# %% [markdown]
# # Which GPU to use

# %%
multiGPU = False
whichGPU = 1
 
# Select which GPU to use
if(multiGPU):
    from keras.utils.training_utils import multi_gpu_model
else:
    import os
    os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID"
    # The GPU id to use, usually either "0" or "1"
    os.environ["CUDA_VISIBLE_DEVICES"] = str(whichGPU)
    
# # Do other imports now...

# %% [markdown]
# # Load all the functions

# %%
# %run -i 'arena.py'
# Out:
# Using TensorFlow backend.

# %% [markdown]
# # General Parameters

# %%
import math

# What data to use
tableBase = '4PpKk'
convertStates = False

# Interactive (just in general if one is asked for confirmations, set to False if on autopilot over night f.x.)
askForConfirmation = False

# NN parameters
filters = [16,32,32,64,128,128,128]
filterShape = [2,2,2,2,2,2,2]
batch_size = 256
optimizer = 'Adadelta'
useBatchNorm = False
num_classes = 3
input_shape = (4,8,8)

### DON'T MODIFY BELOW ###
# Generate dataset variables
fileName = tableBase + '.hdf5'
dataSetName = tableBase + '_onlyLegal'
if not convertStates: 
    dataSetName = tableBase + '_onlyLegal_fullStates'
dataSetWdlName = tableBase + '_Wdl_onlyLegal_3Values'

# Number of Pieces
nPi =  int(dataSetName[0])
nPa = nPi - 2
nWPa = math.ceil(nPa/2)

# %% [markdown]
# # Experiment 1
# Bengio methood
# 3n4  freeze

# %% [markdown]
# ## exp 1 parameters

# %%
# %run -i 'arena.py'

# Parameters
sourceNet = '103' # trained on 3pc from scratch
# sourceNet = '107' # trained on 4pc from scratch ######################## MODIFY
freeze = True                           ############################### MODIFY
epochs = 10
averageOver = 1
                          ############################### MODIFY
expDescrBaseName = "Bengio 3n4 - freeze = {} - average over {} runs - {} epochs".format(str(freeze), averageOver, epochs)

saveEveryRun = True # save stuff in results dir
saveWeightsCheckpoints = False # save chkp in results dit
saveTensorboardLogs = True # save logs in ./logs dir
resID = '---NORESID---' # used when not saving data, but fitModel() still needs a resID

fractionOfDataToUse = 1
plotDuringTraining = False
loadWeights = False 
askForConfirmation = False

# stuff to save in bengioResults dir
resSaveFile = '3n4freeze'
saveDir = 'bengioResults'
resSaveFile = resSaveFile + '-{}runAverage-{}epochs'.format(averageOver, epochs)
resSaveFileFullPath = saveDir + '/' + str(resSaveFile) + '.pkl' 
resSaveFileAllRuns = resSaveFile + '-allRuns'.format(averageOver, epochs)
resSaveFileAllRunsFullPath = saveDir + '/' + str(resSaveFileAllRuns) + '.pkl' 
resSaveFileThisRun = resSaveFile + '-thisRun'.format(averageOver, epochs)
resSaveFileThisRunFullPath = saveDir + '/' + str(resSaveFileThisRun) + '.pkl'

# %% [markdown]
# ### Create model and load data

# %%
# prepare save file
if not os.path.exists(resSaveFileFullPath):
    print("Save file doesn't exists, creating...\n")
    save_obj(saveDir, resSaveFile, [])
else:
    print("Save file exists...\n")
    
if not os.path.exists(resSaveFileAllRunsFullPath):
    print("Save file for all runs doesn't exists, creating...\n")
    save_obj(saveDir, resSaveFileAllRuns, [])
else:
    print("Save file for all runs exists...\n")

if not os.path.exists(resSaveFileThisRunFullPath):
    print("Save file for this run doesn't exists, creating...\n")
    save_obj(saveDir, resSaveFileThisRun, [])
else:
    print("Save file for this run exists...\n")

# load data
X_train, X_test, y_train, y_test = loadData(randomState = None)

# create model
model, nnStr = createModel()
layersCount = len(model.layers)

# load old results
results = load_obj(saveDir, resSaveFile)
resultsAllRuns = load_obj(saveDir, resSaveFileAllRuns)
resultsThisRun = load_obj(saveDir, resSaveFileThisRun)

# initialize variables wrt old results
startTrainingAtLayer = len(results)
print("\nStarting/restarting TL at {} transfered layers".format(startTrainingAtLayer))
startThisRunAt = len(resultsThisRun)
print("\nStarting/restarting TL at average {}".format(startTrainingAtLayer))
# Out:
# Save file exists...
#
# Save file for all runs exists...
#
# Save file for this run exists...
#
# 7436088
# 7436088
# X_train shape: (4982178, 4, 8, 8)
# y_train shape: (4982178, 1)
# X_test shape: (2453910, 4, 8, 8)
# y_test shape: (2453910, 1)
# 4982178 train samples
# 2453910 test samples
# Done loading dataset
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 16, 7, 7)          272
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 15, 6, 32)         928
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 14, 5, 32)         4128
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 13, 4, 64)         8256
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 12, 3, 128)        32896
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 11, 2, 128)        65664
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 10, 1, 128)        65664
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 1280)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 3)                 3843
# =================================================================
# Total params: 181,651
# Trainable params: 181,651
# Non-trainable params: 0
# _________________________________________________________________
# Starting with random weights
# Done creating model
#
# Starting/restarting TL at 0 transfered layers
#
# Starting/restarting TL at average 0

# %%
print(results)
print(resultsThisRun)
print(resultsAllRuns)
# Out:
# []
# []
# []

# %% [markdown]
# ### Train

# %%
# %run -i 'arena.py'

for copyFirstNLayers in range(startTrainingAtLayer, layersCount):
    print('\n\n')
    print('==========================================================================================')
    print('=                                                                                        =')
    print('=                    Currently transfering first {} layers, out of {}                      ='.format(copyFirstNLayers, layersCount - 1))
    print('=                                                                                        =')
    print('==========================================================================================')
    print()
    
    # check if we are at the flatten layer, and skip it if so
    if copyFirstNLayers == layersCount - 1:
        copyFirstNLayers += 1
        
    # start accumulated score from load file in case of starting from average run ≠ 0
    accumulatedScore = np.sum(resultsThisRun)
    
    # train and average results
    for a in range(startThisRunAt,averageOver):
        print('    ==================================================================================')
        print('    =                                                                                =')
        print('    =                Currently at run {}, out of {}                                   ='.format(a+1,averageOver))
        print('    =                                                                                =')
        print('    ==================================================================================')
        print()
        
        # set experement description test
        expDescr = expDescrBaseName + '__copyLayers_{}__average_{}_of_{}'.format(copyFirstNLayers, a+1, averageOver)
        
        # save current averagePosition to tmp file
        with open(saveDir + '/' + str(resSaveFile) + '_currentPosition.txt','w') as file:
            if copyFirstNLayers == layersCount:
                location = copyFirstNLayers - 1
            else:
                location = copyFirstNLayers 
            file.write('Layers Transfered: {} out of {} \nInner avg loop position: {} out of {}'.format(location, layersCount-1, a+1, averageOver))         
            
        # load Model layers
        model = loadNFirstLayers(model, sourceNet, copyFirstNLayers , freeze)

        # Prepare save dir
        if saveEveryRun:
            resID = genNextResultsDir(model)

        # train
        fitHistory, logDir = trainModel(resID, model, saveWeightsCheckpoints, saveTensorboardLogs)

        # score and save results
        score = calcScore(model)
        if saveEveryRun:
            saveTrainResults(resID, model, logDir, score, copyFirstNLayers)

        # update Return
        accumulatedScore += score[1]
        resultsThisRun.append(score[1])
        
        # save checkpoint
        dateTime = time.strftime('%Y-%m-%d-%H:%M:%S', time.localtime())
        
        src = saveDir + '/' + str(resSaveFileThisRun) + '.pkl'
        dest = saveDir + '/checkpoints/' + str(resSaveFileThisRun) + dateTime + '.pkl'
        if os.path.exists(src):
            shutil.move(src, dest)
            
        src = saveDir + '/' + str(resSaveFileThisRun) + '.txt'
        dest = saveDir + '/checkpoints/' + str(resSaveFileThisRun) + dateTime + '.txt'
        if os.path.exists(src):
            shutil.move(src, dest)
        
        # save results 
        save_obj(saveDir, resSaveFileThisRun, resultsThisRun)
        with open(saveDir + '/' + str(resSaveFileThisRun) + '.txt','w') as file:
            file.write(str(resultsThisRun))
            
    # append averaged results for one set of layers
    results.append(accumulatedScore/averageOver)
    resultsAllRuns.append(resultsThisRun)

    # save old results to checkpoints dir
    dateTime = time.strftime('%Y-%m-%d-%H:%M:%S', time.localtime())
    
    src = saveDir + '/' + str(resSaveFile) + '.txt'
    dest = saveDir + '/checkpoints/' + str(resSaveFile) + dateTime + '.txt'
    if os.path.exists(src):
        shutil.move(src, dest)
        
    src = saveDir + '/' + str(resSaveFile) + '.pkl'
    dest = saveDir + '/checkpoints/' + str(resSaveFile) + dateTime + '.pkl'
    if os.path.exists(src):
        shutil.move(src, dest)

    src = saveDir + '/' + str(resSaveFileAllRuns) + '.txt'
    dest = saveDir + '/checkpoints/' + str(resSaveFileAllRuns) + dateTime + '.txt'
    if os.path.exists(src):
        shutil.move(src, dest)
        
    src = saveDir + '/' + str(resSaveFileAllRuns) + '.pkl'
    dest = saveDir + '/checkpoints/' + str(resSaveFileAllRuns) + dateTime + '.pkl'
    if os.path.exists(src):
        shutil.move(src, dest)
        
    # save results 
    save_obj(saveDir, resSaveFile, results)
    with open(saveDir + '/' + str(resSaveFile) + '.txt','w') as file:
        file.write(str(results))
    
    save_obj(saveDir, resSaveFileAllRuns, resultsAllRuns)
    with open(saveDir + '/' + str(resSaveFileAllRuns) + '.txt','w') as file:
        file.write(str(resultsAllRuns))

    # to load:
    # results = load_obj('temp','3n4.txt')
    resultsThisRun = []
print('\n Final Results: {}'.format(results))
# Out:
# ==========================================================================================
# =                                                                                        =
# =                    Currently transfering first 0 layers, out of 8                      =
# =                                                                                        =
# ==========================================================================================
#
#     ==================================================================================
#     =                                                                                =
#     =                Currently at run 1, out of 1                                   =
#     =                                                                                =
#     ==================================================================================
#
# Loading first 0 layers from results Results/103/weights.hdf5,
# - 1: Resetting layer <keras.layers.convolutional.Conv2D object at 0x7fb3d65289b0>
# - 2: Resetting layer <keras.layers.convolutional.Conv2D object at 0x7fb3d6528cc0>
# - 3: Resetting layer <keras.layers.convolutional.Conv2D object at 0x7fb3d6528f28>
# - 4: Resetting layer <keras.layers.convolutional.Conv2D object at 0x7fb3d6528d68>
# - 5: Resetting layer <keras.layers.convolutional.Conv2D object at 0x7fb3d629c128>
# - 6: Resetting layer <keras.layers.convolutional.Conv2D object at 0x7fb3d62bc518>
# - 7: Resetting layer <keras.layers.convolutional.Conv2D object at 0x7fb3d62608d0>
# - 8: Skipping layer <keras.layers.core.Flatten object at 0x7fb3d627cb38>
# - 9: Resetting layer <keras.layers.core.Dense object at 0x7fb3d6219e80>
# Save dir: Results/414/
# Creating save dir
# Done generating results dir Results/414/
# Train on 4982178 samples, validate on 2453910 samples
# Epoch 1/10
# 4982178/4982178 [==============================] - 167s 34us/step - loss: 0.2844 - acc: 0.8770 - val_loss: 0.1896 - val_acc: 0.9210
# Epoch 2/10
# 4982178/4982178 [==============================] - 167s 33us/step - loss: 0.1688 - acc: 0.9295 - val_loss: 0.1629 - val_acc: 0.9332
# Epoch 3/10
# 4982178/4982178 [==============================] - 168s 34us/step - loss: 0.1402 - acc: 0.9422 - val_loss: 0.1357 - val_acc: 0.9441
# Epoch 4/10
# 4982178/4982178 [==============================] - 168s 34us/step - loss: 0.1236 - acc: 0.9495 - val_loss: 0.1243 - val_acc: 0.9497
# Epoch 5/10
# 4982178/4982178 [==============================] - 168s 34us/step - loss: 0.1126 - acc: 0.9543 - val_loss: 0.1172 - val_acc: 0.9527
# Epoch 6/10
# 4982178/4982178 [==============================] - 168s 34us/step - loss: 0.1042 - acc: 0.9579 - val_loss: 0.1062 - val_acc: 0.9572
# Epoch 7/10
# 4982178/4982178 [==============================] - 169s 34us/step - loss: 0.0981 - acc: 0.9607 - val_loss: 0.1020 - val_acc: 0.9591
# Epoch 8/10
# 4982178/4982178 [==============================] - 169s 34us/step - loss: 0.0932 - acc: 0.9628 - val_loss: 0.0960 - val_acc: 0.9619
# Epoch 9/10
# 4982178/4982178 [==============================] - 168s 34us/step - loss: 0.0890 - acc: 0.9645 - val_loss: 0.0988 - val_acc: 0.9608
# Epoch 10/10
# 4982178/4982178 [==============================] - 169s 34us/step - loss: 0.0857 - acc: 0.9659 - val_loss: 0.0938 - val_acc: 0.9629
# Training done
# Calculating score
# 2453910/2453910 [==============================] - 114s 47us/step
# (4982178, 4, 8, 8)
# Evaluated test loss: 0.09384470025586304
# Evaluated test accuracy: 0.9628829093161526
# Saving results to dir 414
# Saving history...
# Saving weights...
# Saving figures...
# Saving summary...
# Saving tensorboard logs...
# All done saving stuff!
#
#
#
# ==========================================================================================
# =                                                                                        =
# =                    Currently transfering first 1 layers, out of 8                      =
# =                                                                                        =
# ==========================================================================================
#
#     ==================================================================================
#     =                                                                                =
#     =                Currently at run 1, out of 1                                   =
#     =                                                                                =
#     ==================================================================================
#
# Loading first 1 layers from results Results/103/weights.hdf5,
# - 1: Freezing layer <keras.layers.convolutional.Conv2D object at 0x7fb3d65289b0>
# - 2: Resetting layer <keras.layers.convolutional.Conv2D object at 0x7fb3d6528cc0>
# - 3: Resetting layer <keras.layers.convolutional.Conv2D object at 0x7fb3d6528f28>
# - 4: Resetting layer <keras.layers.convolutional.Conv2D object at 0x7fb3d6528d68>
# - 5: Resetting layer <keras.layers.convolutional.Conv2D object at 0x7fb3d629c128>
# - 6: Resetting layer <keras.layers.convolutional.Conv2D object at 0x7fb3d62bc518>
# - 7: Resetting layer <keras.layers.convolutional.Conv2D object at 0x7fb3d62608d0>
# - 8: Skipping layer <keras.layers.core.Flatten object at 0x7fb3d627cb38>
# - 9: Resetting layer <keras.layers.core.Dense object at 0x7fb3d6219e80>
# Save dir: Results/416/
# Creating save dir
# Done generating results dir Results/416/
# Train on 4982178 samples, validate on 2453910 samples
# Epoch 1/10
# 4982178/4982178 [==============================] - 157s 32us/step - loss: 0.3552 - acc: 0.8464 - val_loss: 0.2762 - val_acc: 0.8812
# Epoch 2/10
# 4982178/4982178 [==============================] - 158s 32us/step - loss: 0.2335 - acc: 0.9005 - val_loss: 0.2327 - val_acc: 0.9012
# Epoch 3/10
# 4982178/4982178 [==============================] - 158s 32us/step - loss: 0.2015 - acc: 0.9148 - val_loss: 0.1936 - val_acc: 0.9181
# Epoch 4/10
# 4982178/4982178 [==============================] - 158s 32us/step - loss: 0.1836 - acc: 0.9228 - val_loss: 0.1876 - val_acc: 0.9212
# Epoch 5/10
# 4982178/4982178 [==============================] - 158s 32us/step - loss: 0.1722 - acc: 0.9278 - val_loss: 0.1810 - val_acc: 0.9256
# Epoch 6/10
# 4982178/4982178 [==============================] - 158s 32us/step - loss: 0.1641 - acc: 0.9315 - val_loss: 0.1726 - val_acc: 0.9280
# Epoch 7/10
# 4982178/4982178 [==============================] - 158s 32us/step - loss: 0.1580 - acc: 0.9342 - val_loss: 0.1621 - val_acc: 0.9329
# Epoch 8/10
# 4982178/4982178 [==============================] - 158s 32us/step - loss: 0.1534 - acc: 0.9364 - val_loss: 0.1613 - val_acc: 0.9331
# Epoch 9/10
# 4982178/4982178 [==============================] - 158s 32us/step - loss: 0.1498 - acc: 0.9380 - val_loss: 0.1537 - val_acc: 0.9362
# Epoch 10/10
# 4982178/4982178 [==============================] - 158s 32us/step - loss: 0.1471 - acc: 0.9391 - val_loss: 0.1566 - val_acc: 0.9367
# Training done
# Calculating score
# 2453910/2453910 [==============================] - 117s 48us/step
# (4982178, 4, 8, 8)
# Evaluated test loss: 0.15656128044409473
# Evaluated test accuracy: 0.9366944997981353
# Saving results to dir 416
# Saving history...
# Saving weights...
# Saving figures...
# Saving summary...
# Saving tensorboard logs...
# All done saving stuff!
#
#
#
# ==========================================================================================
# =                                                                                        =
# =                    Currently transfering first 2 layers, out of 8                      =
# =                                                                                        =
# ==========================================================================================
#
#     ==================================================================================
#     =                                                                                =
#     =                Currently at run 1, out of 1                                   =
#     =                                                                                =
#     ==================================================================================
#
# Loading first 2 layers from results Results/103/weights.hdf5,
# - 1: Freezing layer <keras.layers.convolutional.Conv2D object at 0x7fb3d65289b0>
# - 2: Freezing layer <keras.layers.convolutional.Conv2D object at 0x7fb3d6528cc0>
# - 3: Resetting layer <keras.layers.convolutional.Conv2D object at 0x7fb3d6528f28>
# - 4: Resetting layer <keras.layers.convolutional.Conv2D object at 0x7fb3d6528d68>
# - 5: Resetting layer <keras.layers.convolutional.Conv2D object at 0x7fb3d629c128>
# - 6: Resetting layer <keras.layers.convolutional.Conv2D object at 0x7fb3d62bc518>
# - 7: Resetting layer <keras.layers.convolutional.Conv2D object at 0x7fb3d62608d0>
# - 8: Skipping layer <keras.layers.core.Flatten object at 0x7fb3d627cb38>
# - 9: Resetting layer <keras.layers.core.Dense object at 0x7fb3d6219e80>
# Save dir: Results/417/
# Creating save dir
# Done generating results dir Results/417/
# Train on 4982178 samples, validate on 2453910 samples
# Epoch 1/10
# 4982178/4982178 [==============================] - 145s 29us/step - loss: 0.3555 - acc: 0.8467 - val_loss: 0.2797 - val_acc: 0.8795
# Epoch 2/10
# 4982178/4982178 [==============================] - 146s 29us/step - loss: 0.2423 - acc: 0.8974 - val_loss: 0.2295 - val_acc: 0.9032
# Epoch 3/10
# 4982178/4982178 [==============================] - 147s 29us/step - loss: 0.2130 - acc: 0.9103 - val_loss: 0.2062 - val_acc: 0.9137
# Epoch 4/10
# 4982178/4982178 [==============================] - 146s 29us/step - loss: 0.1972 - acc: 0.9173 - val_loss: 0.2000 - val_acc: 0.9164
# Epoch 5/10
# 4982178/4982178 [==============================] - 147s 29us/step - loss: 0.1865 - acc: 0.9221 - val_loss: 0.1916 - val_acc: 0.9198
# Epoch 6/10
# 4982178/4982178 [==============================] - 146s 29us/step - loss: 0.1787 - acc: 0.9254 - val_loss: 0.1854 - val_acc: 0.9226
# Epoch 7/10
# 4982178/4982178 [==============================] - 146s 29us/step - loss: 0.1729 - acc: 0.9281 - val_loss: 0.1791 - val_acc: 0.9260
# Epoch 8/10
# 4982178/4982178 [==============================] - 147s 29us/step - loss: 0.1683 - acc: 0.9301 - val_loss: 0.1707 - val_acc: 0.9290
# Epoch 9/10
# 4982178/4982178 [==============================] - 145s 29us/step - loss: 0.1643 - acc: 0.9320 - val_loss: 0.1796 - val_acc: 0.9268
# Epoch 10/10
# 4982178/4982178 [==============================] - 144s 29us/step - loss: 0.1616 - acc: 0.9331 - val_loss: 0.1725 - val_acc: 0.9290
# Training done
# Calculating score
# 2453910/2453910 [==============================] - 117s 48us/step
# (4982178, 4, 8, 8)
# Evaluated test loss: 0.17253109245360063
# Evaluated test accuracy: 0.9290063612764934
# Saving results to dir 417
# Saving history...
# Saving weights...
# Saving figures...
# Saving summary...
# Saving tensorboard logs...
# All done saving stuff!
#
#
#
# ==========================================================================================
# =                                                                                        =
# =                    Currently transfering first 3 layers, out of 8                      =
# =                                                                                        =
# ==========================================================================================
#
#     ==================================================================================
#     =                                                                                =
#     =                Currently at run 1, out of 1                                   =
#     =                                                                                =
#     ==================================================================================
#
# Loading first 3 layers from results Results/103/weights.hdf5,
# - 1: Freezing layer <keras.layers.convolutional.Conv2D object at 0x7fb3d65289b0>
# - 2: Freezing layer <keras.layers.convolutional.Conv2D object at 0x7fb3d6528cc0>
# - 3: Freezing layer <keras.layers.convolutional.Conv2D object at 0x7fb3d6528f28>
# - 4: Resetting layer <keras.layers.convolutional.Conv2D object at 0x7fb3d6528d68>
# - 5: Resetting layer <keras.layers.convolutional.Conv2D object at 0x7fb3d629c128>
# - 6: Resetting layer <keras.layers.convolutional.Conv2D object at 0x7fb3d62bc518>
# - 7: Resetting layer <keras.layers.convolutional.Conv2D object at 0x7fb3d62608d0>
# - 8: Skipping layer <keras.layers.core.Flatten object at 0x7fb3d627cb38>
# - 9: Resetting layer <keras.layers.core.Dense object at 0x7fb3d6219e80>
# Save dir: Results/419/
# Creating save dir
# Done generating results dir Results/419/
# Train on 4982178 samples, validate on 2453910 samples
# Epoch 1/10
# 4982178/4982178 [==============================] - 132s 27us/step - loss: 0.3684 - acc: 0.8426 - val_loss: 0.2858 - val_acc: 0.8807
# Epoch 2/10
# 4982178/4982178 [==============================] - 132s 26us/step - loss: 0.2618 - acc: 0.8902 - val_loss: 0.2478 - val_acc: 0.8962
# Epoch 3/10
# 4982178/4982178 [==============================] - 133s 27us/step - loss: 0.2339 - acc: 0.9022 - val_loss: 0.2301 - val_acc: 0.9038
# Epoch 4/10
# 4982178/4982178 [==============================] - 133s 27us/step - loss: 0.2182 - acc: 0.9093 - val_loss: 0.2186 - val_acc: 0.9094
# Epoch 5/10
# 4982178/4982178 [==============================] - 133s 27us/step - loss: 0.2074 - acc: 0.9139 - val_loss: 0.2145 - val_acc: 0.9107
# Epoch 6/10
# 4982178/4982178 [==============================] - 133s 27us/step - loss: 0.1998 - acc: 0.9172 - val_loss: 0.2111 - val_acc: 0.9130
# Epoch 7/10
# 4982178/4982178 [==============================] - 133s 27us/step - loss: 0.1939 - acc: 0.9197 - val_loss: 0.2059 - val_acc: 0.9154
# Epoch 8/10
# 4982178/4982178 [==============================] - 133s 27us/step - loss: 0.1892 - acc: 0.9219 - val_loss: 0.2004 - val_acc: 0.9177
# Epoch 9/10
# 4982178/4982178 [==============================] - 133s 27us/step - loss: 0.1853 - acc: 0.9236 - val_loss: 0.1989 - val_acc: 0.9174
# Epoch 10/10
# 4982178/4982178 [==============================] - 133s 27us/step - loss: 0.1820 - acc: 0.9250 - val_loss: 0.1937 - val_acc: 0.9205
# Training done
# Calculating score
# 2453910/2453910 [==============================] - 118s 48us/step
# (4982178, 4, 8, 8)
# Evaluated test loss: 0.19368342514458364
# Evaluated test accuracy: 0.9204551104158654
# Saving results to dir 419
# Saving history...
# Saving weights...
# Saving figures...
# Saving summary...
# Saving tensorboard logs...
# All done saving stuff!
#
#
#
# ==========================================================================================
# =                                                                                        =
# =                    Currently transfering first 4 layers, out of 8                      =
# =                                                                                        =
# ==========================================================================================
#
#     ==================================================================================
#     =                                                                                =
#     =                Currently at run 1, out of 1                                   =
#     =                                                                                =
#     ==================================================================================
#
# Loading first 4 layers from results Results/103/weights.hdf5,
# - 1: Freezing layer <keras.layers.convolutional.Conv2D object at 0x7fb3d65289b0>
# - 2: Freezing layer <keras.layers.convolutional.Conv2D object at 0x7fb3d6528cc0>
# - 3: Freezing layer <keras.layers.convolutional.Conv2D object at 0x7fb3d6528f28>
# - 4: Freezing layer <keras.layers.convolutional.Conv2D object at 0x7fb3d6528d68>
# - 5: Resetting layer <keras.layers.convolutional.Conv2D object at 0x7fb3d629c128>
# - 6: Resetting layer <keras.layers.convolutional.Conv2D object at 0x7fb3d62bc518>
# - 7: Resetting layer <keras.layers.convolutional.Conv2D object at 0x7fb3d62608d0>
# - 8: Skipping layer <keras.layers.core.Flatten object at 0x7fb3d627cb38>
# - 9: Resetting layer <keras.layers.core.Dense object at 0x7fb3d6219e80>
# Save dir: Results/421/
# Creating save dir
# Done generating results dir Results/421/
# Train on 4982178 samples, validate on 2453910 samples
# Epoch 1/10
# 4982178/4982178 [==============================] - 123s 25us/step - loss: 0.3879 - acc: 0.8349 - val_loss: 0.3118 - val_acc: 0.8696
# Epoch 2/10
# 4982178/4982178 [==============================] - 123s 25us/step - loss: 0.2891 - acc: 0.8794 - val_loss: 0.2810 - val_acc: 0.8844
# Epoch 3/10
# 4982178/4982178 [==============================] - 123s 25us/step - loss: 0.2622 - acc: 0.8909 - val_loss: 0.2585 - val_acc: 0.8932
# Epoch 4/10
# 4982178/4982178 [==============================] - 123s 25us/step - loss: 0.2466 - acc: 0.8976 - val_loss: 0.2475 - val_acc: 0.8978
# Epoch 5/10
# 4982178/4982178 [==============================] - 123s 25us/step - loss: 0.2358 - acc: 0.9023 - val_loss: 0.2397 - val_acc: 0.9013
# Epoch 6/10
# 4982178/4982178 [==============================] - 123s 25us/step - loss: 0.2282 - acc: 0.9056 - val_loss: 0.2383 - val_acc: 0.9020
# Epoch 7/10
# 4982178/4982178 [==============================] - 122s 25us/step - loss: 0.2222 - acc: 0.9083 - val_loss: 0.2343 - val_acc: 0.9043
# Epoch 8/10
# 4982178/4982178 [==============================] - 123s 25us/step - loss: 0.2175 - acc: 0.9104 - val_loss: 0.2291 - val_acc: 0.9060
# Epoch 9/10
# 4982178/4982178 [==============================] - 123s 25us/step - loss: 0.2135 - acc: 0.9120 - val_loss: 0.2314 - val_acc: 0.9052
# Epoch 10/10
# 4982178/4982178 [==============================] - 123s 25us/step - loss: 0.2103 - acc: 0.9135 - val_loss: 0.2237 - val_acc: 0.9080
# Training done
# Calculating score
# 2453910/2453910 [==============================] - 119s 48us/step
# (4982178, 4, 8, 8)
# Evaluated test loss: 0.22366751105477542
# Evaluated test accuracy: 0.9079725825317946
# Saving results to dir 421
# Saving history...
# Saving weights...
# Saving figures...
# Saving summary...
# Saving tensorboard logs...
# All done saving stuff!
#
#
#
# ==========================================================================================
# =                                                                                        =
# =                    Currently transfering first 5 layers, out of 8                      =
# =                                                                                        =
# ==========================================================================================
#
#     ==================================================================================
#     =                                                                                =
#     =                Currently at run 1, out of 1                                   =
#     =                                                                                =
#     ==================================================================================
#
# Loading first 5 layers from results Results/103/weights.hdf5,
# - 1: Freezing layer <keras.layers.convolutional.Conv2D object at 0x7fb3d65289b0>
# - 2: Freezing layer <keras.layers.convolutional.Conv2D object at 0x7fb3d6528cc0>
# - 3: Freezing layer <keras.layers.convolutional.Conv2D object at 0x7fb3d6528f28>
# - 4: Freezing layer <keras.layers.convolutional.Conv2D object at 0x7fb3d6528d68>
# - 5: Freezing layer <keras.layers.convolutional.Conv2D object at 0x7fb3d629c128>
# - 6: Resetting layer <keras.layers.convolutional.Conv2D object at 0x7fb3d62bc518>
# - 7: Resetting layer <keras.layers.convolutional.Conv2D object at 0x7fb3d62608d0>
# - 8: Skipping layer <keras.layers.core.Flatten object at 0x7fb3d627cb38>
# - 9: Resetting layer <keras.layers.core.Dense object at 0x7fb3d6219e80>
# Save dir: Results/423/
# Creating save dir
# Done generating results dir Results/423/
# Train on 4982178 samples, validate on 2453910 samples
# Epoch 1/10
# 4982178/4982178 [==============================] - 112s 23us/step - loss: 0.4472 - acc: 0.8094 - val_loss: 0.3847 - val_acc: 0.8383
# Epoch 2/10
# 4982178/4982178 [==============================] - 112s 23us/step - loss: 0.3537 - acc: 0.8526 - val_loss: 0.3432 - val_acc: 0.8574
# Epoch 3/10
# 4982178/4982178 [==============================] - 112s 22us/step - loss: 0.3267 - acc: 0.8644 - val_loss: 0.3289 - val_acc: 0.8635
# Epoch 4/10
# 4982178/4982178 [==============================] - 112s 22us/step - loss: 0.3115 - acc: 0.8711 - val_loss: 0.3178 - val_acc: 0.8687
# Epoch 5/10
# 4982178/4982178 [==============================] - 111s 22us/step - loss: 0.3006 - acc: 0.8759 - val_loss: 0.3109 - val_acc: 0.8716
# Epoch 6/10
# 4982178/4982178 [==============================] - 111s 22us/step - loss: 0.2933 - acc: 0.8790 - val_loss: 0.3056 - val_acc: 0.8736
# Epoch 7/10
# 4982178/4982178 [==============================] - 111s 22us/step - loss: 0.2872 - acc: 0.8816 - val_loss: 0.3084 - val_acc: 0.8747
# Epoch 8/10
# 4982178/4982178 [==============================] - 111s 22us/step - loss: 0.2824 - acc: 0.8837 - val_loss: 0.2947 - val_acc: 0.8795
# Epoch 9/10
# 4982178/4982178 [==============================] - 111s 22us/step - loss: 0.2783 - acc: 0.8854 - val_loss: 0.2934 - val_acc: 0.8793
# Epoch 10/10
# 4982178/4982178 [==============================] - 111s 22us/step - loss: 0.2748 - acc: 0.8871 - val_loss: 0.2950 - val_acc: 0.8783
# Training done
# Calculating score
# 2453910/2453910 [==============================] - 120s 49us/step
# (4982178, 4, 8, 8)
# Evaluated test loss: 0.29496717524832317
# Evaluated test accuracy: 0.8783480241739086
# Saving results to dir 423
# Saving history...
# Saving weights...
# Saving figures...
# Saving summary...
# Saving tensorboard logs...
# All done saving stuff!
#
#
#
# ==========================================================================================
# =                                                                                        =
# =                    Currently transfering first 6 layers, out of 8                      =
# =                                                                                        =
# ==========================================================================================
#
#     ==================================================================================
#     =                                                                                =
#     =                Currently at run 1, out of 1                                   =
#     =                                                                                =
#     ==================================================================================
#
# Loading first 6 layers from results Results/103/weights.hdf5,
# - 1: Freezing layer <keras.layers.convolutional.Conv2D object at 0x7fb3d65289b0>
# - 2: Freezing layer <keras.layers.convolutional.Conv2D object at 0x7fb3d6528cc0>
# - 3: Freezing layer <keras.layers.convolutional.Conv2D object at 0x7fb3d6528f28>
# - 4: Freezing layer <keras.layers.convolutional.Conv2D object at 0x7fb3d6528d68>
# - 5: Freezing layer <keras.layers.convolutional.Conv2D object at 0x7fb3d629c128>
# - 6: Freezing layer <keras.layers.convolutional.Conv2D object at 0x7fb3d62bc518>
# - 7: Resetting layer <keras.layers.convolutional.Conv2D object at 0x7fb3d62608d0>
# - 8: Skipping layer <keras.layers.core.Flatten object at 0x7fb3d627cb38>
# - 9: Resetting layer <keras.layers.core.Dense object at 0x7fb3d6219e80>
# Save dir: Results/425/
# Creating save dir
# Done generating results dir Results/425/
# Train on 4982178 samples, validate on 2453910 samples
# Epoch 1/10
# 4982178/4982178 [==============================] - 102s 20us/step - loss: 0.5594 - acc: 0.7570 - val_loss: 0.5142 - val_acc: 0.7820
# Epoch 2/10
# 4982178/4982178 [==============================] - 101s 20us/step - loss: 0.4843 - acc: 0.7941 - val_loss: 0.4750 - val_acc: 0.7985
# Epoch 3/10
# 4982178/4982178 [==============================] - 101s 20us/step - loss: 0.4617 - acc: 0.8048 - val_loss: 0.4694 - val_acc: 0.8030
# Epoch 4/10
# 4982178/4982178 [==============================] - 101s 20us/step - loss: 0.4488 - acc: 0.8109 - val_loss: 0.4605 - val_acc: 0.8062
# Epoch 5/10
# 4982178/4982178 [==============================] - 101s 20us/step - loss: 0.4402 - acc: 0.8150 - val_loss: 0.4479 - val_acc: 0.8116
# Epoch 6/10
# 4982178/4982178 [==============================] - 101s 20us/step - loss: 0.4334 - acc: 0.8179 - val_loss: 0.4390 - val_acc: 0.8156
# Epoch 7/10
# 4982178/4982178 [==============================] - 101s 20us/step - loss: 0.4285 - acc: 0.8204 - val_loss: 0.4378 - val_acc: 0.8165
# Epoch 8/10
# 4982178/4982178 [==============================] - 101s 20us/step - loss: 0.4243 - acc: 0.8222 - val_loss: 0.4366 - val_acc: 0.8179
# Epoch 9/10
# 4982178/4982178 [==============================] - 101s 20us/step - loss: 0.4210 - acc: 0.8237 - val_loss: 0.4310 - val_acc: 0.8206
# Epoch 10/10
# 4982178/4982178 [==============================] - 101s 20us/step - loss: 0.4180 - acc: 0.8253 - val_loss: 0.4269 - val_acc: 0.8218
# Training done
# Calculating score
# 2453910/2453910 [==============================] - 120s 49us/step
# (4982178, 4, 8, 8)
# Evaluated test loss: 0.4269071272219034
# Evaluated test accuracy: 0.8217909377279039
# Saving results to dir 425
# Saving history...
# Saving weights...
# Saving figures...
# Saving summary...
# Saving tensorboard logs...
# All done saving stuff!
#
#
#
# ==========================================================================================
# =                                                                                        =
# =                    Currently transfering first 7 layers, out of 8                      =
# =                                                                                        =
# ==========================================================================================
#
#     ==================================================================================
#     =                                                                                =
#     =                Currently at run 1, out of 1                                   =
#     =                                                                                =
#     ==================================================================================
#
# Loading first 7 layers from results Results/103/weights.hdf5,
# - 1: Freezing layer <keras.layers.convolutional.Conv2D object at 0x7fb3d65289b0>
# - 2: Freezing layer <keras.layers.convolutional.Conv2D object at 0x7fb3d6528cc0>
# - 3: Freezing layer <keras.layers.convolutional.Conv2D object at 0x7fb3d6528f28>
# - 4: Freezing layer <keras.layers.convolutional.Conv2D object at 0x7fb3d6528d68>
# - 5: Freezing layer <keras.layers.convolutional.Conv2D object at 0x7fb3d629c128>
# - 6: Freezing layer <keras.layers.convolutional.Conv2D object at 0x7fb3d62bc518>
# - 7: Freezing layer <keras.layers.convolutional.Conv2D object at 0x7fb3d62608d0>
# - 8: Skipping layer <keras.layers.core.Flatten object at 0x7fb3d627cb38>
# - 9: Resetting layer <keras.layers.core.Dense object at 0x7fb3d6219e80>
# Save dir: Results/426/
# Creating save dir
# Done generating results dir Results/426/
# Train on 4982178 samples, validate on 2453910 samples
# Epoch 1/10
# 4982178/4982178 [==============================] - 89s 18us/step - loss: 0.8005 - acc: 0.6390 - val_loss: 0.7566 - val_acc: 0.6571
# Epoch 2/10
# 4982178/4982178 [==============================] - 89s 18us/step - loss: 0.7928 - acc: 0.6433 - val_loss: 0.7469 - val_acc: 0.6581
# Epoch 3/10
# 4982178/4982178 [==============================] - 89s 18us/step - loss: 0.7921 - acc: 0.6438 - val_loss: 0.8522 - val_acc: 0.6390
# Epoch 4/10
# 4982178/4982178 [==============================] - 89s 18us/step - loss: 0.7923 - acc: 0.6437 - val_loss: 0.8076 - val_acc: 0.6446
# Epoch 5/10
# 4982178/4982178 [==============================] - 89s 18us/step - loss: 0.7941 - acc: 0.6431 - val_loss: 0.7520 - val_acc: 0.6586
# Epoch 6/10
# 4982178/4982178 [==============================] - 89s 18us/step - loss: 0.7923 - acc: 0.6436 - val_loss: 0.8945 - val_acc: 0.6221
# Epoch 7/10
# 4982178/4982178 [==============================] - 89s 18us/step - loss: 0.7921 - acc: 0.6439 - val_loss: 0.7643 - val_acc: 0.6579
# Epoch 8/10
# 4982178/4982178 [==============================] - 89s 18us/step - loss: 0.7933 - acc: 0.6430 - val_loss: 0.7551 - val_acc: 0.6592
# Epoch 9/10
# 4982178/4982178 [==============================] - 89s 18us/step - loss: 0.7917 - acc: 0.6437 - val_loss: 0.7463 - val_acc: 0.6627
# Epoch 10/10
# 4982178/4982178 [==============================] - 88s 18us/step - loss: 0.7917 - acc: 0.6438 - val_loss: 0.7420 - val_acc: 0.6615
# Training done
# Calculating score
# 2453910/2453910 [==============================] - 121s 49us/step
# (4982178, 4, 8, 8)
# Evaluated test loss: 0.7420139418771431
# Evaluated test accuracy: 0.6615136659454902
# Saving results to dir 426
# Saving history...
# Saving weights...
# Saving figures...
# Saving summary...
# Saving tensorboard logs...
# All done saving stuff!
#
#
#
# ==========================================================================================
# =                                                                                        =
# =                    Currently transfering first 8 layers, out of 8                      =
# =                                                                                        =
# ==========================================================================================
#
#     ==================================================================================
#     =                                                                                =
#     =                Currently at run 1, out of 1                                   =
#     =                                                                                =
#     ==================================================================================
#
# Loading first 9 layers from results Results/103/weights.hdf5,
# - 1: Freezing layer <keras.layers.convolutional.Conv2D object at 0x7fb3d65289b0>
# - 2: Freezing layer <keras.layers.convolutional.Conv2D object at 0x7fb3d6528cc0>
# - 3: Freezing layer <keras.layers.convolutional.Conv2D object at 0x7fb3d6528f28>
# - 4: Freezing layer <keras.layers.convolutional.Conv2D object at 0x7fb3d6528d68>
# - 5: Freezing layer <keras.layers.convolutional.Conv2D object at 0x7fb3d629c128>
# - 6: Freezing layer <keras.layers.convolutional.Conv2D object at 0x7fb3d62bc518>
# - 7: Freezing layer <keras.layers.convolutional.Conv2D object at 0x7fb3d62608d0>
# - 8: Skipping layer <keras.layers.core.Flatten object at 0x7fb3d627cb38>
# - 9: Freezing layer <keras.layers.core.Dense object at 0x7fb3d6219e80>
# Save dir: Results/428/
# Creating save dir
# Done generating results dir Results/428/
# Train on 4982178 samples, validate on 2453910 samples
# Epoch 1/10
# 4982178/4982178 [==============================] - 66s 13us/step - loss: 6.8293 - acc: 0.5711 - val_loss: 6.8341 - val_acc: 0.5708
# Epoch 2/10
# 4982178/4982178 [==============================] - 66s 13us/step - loss: 6.8293 - acc: 0.5711 - val_loss: 6.8341 - val_acc: 0.5708
# Epoch 3/10
# 4982178/4982178 [==============================] - 66s 13us/step - loss: 6.8293 - acc: 0.5711 - val_loss: 6.8341 - val_acc: 0.5708
# Epoch 4/10
# 4982178/4982178 [==============================] - 66s 13us/step - loss: 6.8293 - acc: 0.5711 - val_loss: 6.8341 - val_acc: 0.5708
# Epoch 5/10
# 4982178/4982178 [==============================] - 66s 13us/step - loss: 6.8293 - acc: 0.5711 - val_loss: 6.8341 - val_acc: 0.5708
# Epoch 6/10
# 4982178/4982178 [==============================] - 66s 13us/step - loss: 6.8293 - acc: 0.5711 - val_loss: 6.8341 - val_acc: 0.5708
# Epoch 7/10
# 4982178/4982178 [==============================] - 66s 13us/step - loss: 6.8293 - acc: 0.5711 - val_loss: 6.8341 - val_acc: 0.5708
# Epoch 8/10
# 4982178/4982178 [==============================] - 66s 13us/step - loss: 6.8293 - acc: 0.5711 - val_loss: 6.8341 - val_acc: 0.5708
# Epoch 9/10
# 4982178/4982178 [==============================] - 66s 13us/step - loss: 6.8293 - acc: 0.5711 - val_loss: 6.8341 - val_acc: 0.5708
# Epoch 10/10
# 4982178/4982178 [==============================] - 66s 13us/step - loss: 6.8293 - acc: 0.5711 - val_loss: 6.8341 - val_acc: 0.5708
# Training done
# Calculating score
# 2453910/2453910 [==============================] - 121s 49us/step
# (4982178, 4, 8, 8)
# Evaluated test loss: 6.834067108548248
# Evaluated test accuracy: 0.5708049602468729
# Saving results to dir 428
# Saving history...
# Saving weights...
# Saving figures...
# Saving summary...
# Saving tensorboard logs...
# All done saving stuff!
#
#  Final Results: [0.9628829093161526, 0.9366944997981353, 0.9290063612764934, 0.9204551104158654, 0.9079725825317946, 0.8783480241739086, 0.8217909377279039, 0.6615136659454902, 0.5708049602468729]

# %% [markdown]
# # Experiment 2
# Bengio methood
# 4n4 freeze

# %% [markdown]
# ## exp 2 parameters

# %%
# %run -i 'arena.py'

# Parameters
# sourceNet = '103' # trained on 3pc from scratch
sourceNet = '107' # trained on 4pc from scratch ######################## MODIFY
freeze = True                           ############################### MODIFY
epochs = 10
averageOver = 1
                          ############################### MODIFY
expDescrBaseName = "Bengio 4n4 - freeze = {} - average over {} runs - {} epochs".format(str(freeze), averageOver, epochs)

saveEveryRun = True # save stuff in results dir
saveWeightsCheckpoints = False # save chkp in results dit
saveTensorboardLogs = True # save logs in ./logs dir
resID = '---NORESID---' # used when not saving data, but fitModel() still needs a resID

fractionOfDataToUse = 1
plotDuringTraining = False
loadWeights = False 
askForConfirmation = False

# stuff to save in bengioResults dir
resSaveFile = '4n4freeze'
saveDir = 'bengioResults'
resSaveFile = resSaveFile + '-{}runAverage-{}epochs'.format(averageOver, epochs)
resSaveFileFullPath = saveDir + '/' + str(resSaveFile) + '.pkl' 
resSaveFileAllRuns = resSaveFile + '-allRuns'.format(averageOver, epochs)
resSaveFileAllRunsFullPath = saveDir + '/' + str(resSaveFileAllRuns) + '.pkl' 
resSaveFileThisRun = resSaveFile + '-thisRun'.format(averageOver, epochs)
resSaveFileThisRunFullPath = saveDir + '/' + str(resSaveFileThisRun) + '.pkl'

# %% [markdown]
# ### Create model and load data

# %%
# prepare save file
if not os.path.exists(resSaveFileFullPath):
    print("Save file doesn't exists, creating...\n")
    save_obj(saveDir, resSaveFile, [])
else:
    print("Save file exists...\n")
    
if not os.path.exists(resSaveFileAllRunsFullPath):
    print("Save file for all runs doesn't exists, creating...\n")
    save_obj(saveDir, resSaveFileAllRuns, [])
else:
    print("Save file for all runs exists...\n")

if not os.path.exists(resSaveFileThisRunFullPath):
    print("Save file for this run doesn't exists, creating...\n")
    save_obj(saveDir, resSaveFileThisRun, [])
else:
    print("Save file for this run exists...\n")

# load data
X_train, X_test, y_train, y_test = loadData(randomState = None)

# create model
model, nnStr = createModel()
layersCount = len(model.layers)

# load old results
results = load_obj(saveDir, resSaveFile)
resultsAllRuns = load_obj(saveDir, resSaveFileAllRuns)
resultsThisRun = load_obj(saveDir, resSaveFileThisRun)

# initialize variables wrt old results
startTrainingAtLayer = len(results)
print("\nStarting/restarting TL at {} transfered layers".format(startTrainingAtLayer))
startThisRunAt = len(resultsThisRun)
print("\nStarting/restarting TL at average {}".format(startTrainingAtLayer))
# Out:
# Save file doesn't exists, creating...
#
# Save file for all runs doesn't exists, creating...
#
# Save file for this run doesn't exists, creating...
#
# 7436088
# 7436088
# X_train shape: (4982178, 4, 8, 8)
# y_train shape: (4982178, 1)
# X_test shape: (2453910, 4, 8, 8)
# y_test shape: (2453910, 1)
# 4982178 train samples
# 2453910 test samples
# Done loading dataset
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_8 (Conv2D)            (None, 16, 7, 7)          272
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 15, 6, 32)         928
# _________________________________________________________________
# conv2d_10 (Conv2D)           (None, 14, 5, 32)         4128
# _________________________________________________________________
# conv2d_11 (Conv2D)           (None, 13, 4, 64)         8256
# _________________________________________________________________
# conv2d_12 (Conv2D)           (None, 12, 3, 128)        32896
# _________________________________________________________________
# conv2d_13 (Conv2D)           (None, 11, 2, 128)        65664
# _________________________________________________________________
# conv2d_14 (Conv2D)           (None, 10, 1, 128)        65664
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 1280)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 3)                 3843
# =================================================================
# Total params: 181,651
# Trainable params: 181,651
# Non-trainable params: 0
# _________________________________________________________________
# Starting with random weights
# Done creating model
#
# Starting/restarting TL at 0 transfered layers
#
# Starting/restarting TL at average 0

# %%
print(results)
print(resultsThisRun)
print(resultsAllRuns)
# Out:
# []
# []
# []

# %% [markdown]
# ### Train

# %%
# %run -i 'arena.py'

for copyFirstNLayers in range(startTrainingAtLayer, layersCount):
    print('\n\n')
    print('==========================================================================================')
    print('=                                                                                        =')
    print('=                    Currently transfering first {} layers, out of {}                      ='.format(copyFirstNLayers, layersCount - 1))
    print('=                                                                                        =')
    print('==========================================================================================')
    print()
    
    # check if we are at the flatten layer, and skip it if so
    if copyFirstNLayers == layersCount - 1:
        copyFirstNLayers += 1
        
    # start accumulated score from load file in case of starting from average run ≠ 0
    accumulatedScore = np.sum(resultsThisRun)
    
    # train and average results
    for a in range(startThisRunAt,averageOver):
        print('    ==================================================================================')
        print('    =                                                                                =')
        print('    =                Currently at run {}, out of {}                                   ='.format(a+1,averageOver))
        print('    =                                                                                =')
        print('    ==================================================================================')
        print()
        
        # set experement description test
        expDescr = expDescrBaseName + '__copyLayers_{}__average_{}_of_{}'.format(copyFirstNLayers, a+1, averageOver)
        
        # save current averagePosition to tmp file
        with open(saveDir + '/' + str(resSaveFile) + '_currentPosition.txt','w') as file:
            if copyFirstNLayers == layersCount:
                location = copyFirstNLayers - 1
            else:
                location = copyFirstNLayers 
            file.write('Layers Transfered: {} out of {} \nInner avg loop position: {} out of {}'.format(location, layersCount-1, a+1, averageOver))         
            
        # load Model layers
        model = loadNFirstLayers(model, sourceNet, copyFirstNLayers , freeze)

        # Prepare save dir
        if saveEveryRun:
            resID = genNextResultsDir(model)

        # train
        fitHistory, logDir = trainModel(resID, model, saveWeightsCheckpoints, saveTensorboardLogs)

        # score and save results
        score = calcScore(model)
        if saveEveryRun:
            saveTrainResults(resID, model, logDir, score, copyFirstNLayers)

        # update Return
        accumulatedScore += score[1]
        resultsThisRun.append(score[1])
        
        # save checkpoint
        dateTime = time.strftime('%Y-%m-%d-%H:%M:%S', time.localtime())
        
        src = saveDir + '/' + str(resSaveFileThisRun) + '.pkl'
        dest = saveDir + '/checkpoints/' + str(resSaveFileThisRun) + dateTime + '.pkl'
        if os.path.exists(src):
            shutil.move(src, dest)
            
        src = saveDir + '/' + str(resSaveFileThisRun) + '.txt'
        dest = saveDir + '/checkpoints/' + str(resSaveFileThisRun) + dateTime + '.txt'
        if os.path.exists(src):
            shutil.move(src, dest)
        
        # save results 
        save_obj(saveDir, resSaveFileThisRun, resultsThisRun)
        with open(saveDir + '/' + str(resSaveFileThisRun) + '.txt','w') as file:
            file.write(str(resultsThisRun))
            
    # append averaged results for one set of layers
    results.append(accumulatedScore/averageOver)
    resultsAllRuns.append(resultsThisRun)

    # save old results to checkpoints dir
    dateTime = time.strftime('%Y-%m-%d-%H:%M:%S', time.localtime())
    
    src = saveDir + '/' + str(resSaveFile) + '.txt'
    dest = saveDir + '/checkpoints/' + str(resSaveFile) + dateTime + '.txt'
    if os.path.exists(src):
        shutil.move(src, dest)
        
    src = saveDir + '/' + str(resSaveFile) + '.pkl'
    dest = saveDir + '/checkpoints/' + str(resSaveFile) + dateTime + '.pkl'
    if os.path.exists(src):
        shutil.move(src, dest)

    src = saveDir + '/' + str(resSaveFileAllRuns) + '.txt'
    dest = saveDir + '/checkpoints/' + str(resSaveFileAllRuns) + dateTime + '.txt'
    if os.path.exists(src):
        shutil.move(src, dest)
        
    src = saveDir + '/' + str(resSaveFileAllRuns) + '.pkl'
    dest = saveDir + '/checkpoints/' + str(resSaveFileAllRuns) + dateTime + '.pkl'
    if os.path.exists(src):
        shutil.move(src, dest)
        
    # save results 
    save_obj(saveDir, resSaveFile, results)
    with open(saveDir + '/' + str(resSaveFile) + '.txt','w') as file:
        file.write(str(results))
    
    save_obj(saveDir, resSaveFileAllRuns, resultsAllRuns)
    with open(saveDir + '/' + str(resSaveFileAllRuns) + '.txt','w') as file:
        file.write(str(resultsAllRuns))

    # to load:
    # results = load_obj('temp','3n4.txt')
    resultsThisRun = []
print('\n Final Results: {}'.format(results))
# Out:
# ==========================================================================================
# =                                                                                        =
# =                    Currently transfering first 0 layers, out of 8                      =
# =                                                                                        =
# ==========================================================================================
#
#     ==================================================================================
#     =                                                                                =
#     =                Currently at run 1, out of 1                                   =
#     =                                                                                =
#     ==================================================================================
#
# Loading first 0 layers from results Results/107/weights.hdf5,
# - 1: Resetting layer <keras.layers.convolutional.Conv2D object at 0x7fb3d618a710>
# - 2: Resetting layer <keras.layers.convolutional.Conv2D object at 0x7fb3d6522d30>
# - 3: Resetting layer <keras.layers.convolutional.Conv2D object at 0x7fb3d65229b0>
# - 4: Resetting layer <keras.layers.convolutional.Conv2D object at 0x7fb3d65222b0>
# - 5: Resetting layer <keras.layers.convolutional.Conv2D object at 0x7fb03f7498d0>
# - 6: Resetting layer <keras.layers.convolutional.Conv2D object at 0x7fb03f76f198>
# - 7: Resetting layer <keras.layers.convolutional.Conv2D object at 0x7fb03e6410b8>
# - 8: Skipping layer <keras.layers.core.Flatten object at 0x7fb03e67f438>
# - 9: Resetting layer <keras.layers.core.Dense object at 0x7fb03e2abda0>
# Save dir: Results/429/
# Creating save dir
# Done generating results dir Results/429/
# Train on 4982178 samples, validate on 2453910 samples
# Epoch 1/10
# 4982178/4982178 [==============================] - 173s 35us/step - loss: 0.3615 - acc: 0.8384 - val_loss: 0.2406 - val_acc: 0.8983
# Epoch 2/10
# 4982178/4982178 [==============================] - 173s 35us/step - loss: 0.2187 - acc: 0.9081 - val_loss: 0.2033 - val_acc: 0.9148
# Epoch 3/10
# 4982178/4982178 [==============================] - 174s 35us/step - loss: 0.1901 - acc: 0.9208 - val_loss: 0.1823 - val_acc: 0.9239
# Epoch 4/10
# 4982178/4982178 [==============================] - 173s 35us/step - loss: 0.1744 - acc: 0.9274 - val_loss: 0.1746 - val_acc: 0.9274
# Epoch 5/10
# 4982178/4982178 [==============================] - 174s 35us/step - loss: 0.1638 - acc: 0.9321 - val_loss: 0.1667 - val_acc: 0.9307
# Epoch 6/10
# 4982178/4982178 [==============================] - 174s 35us/step - loss: 0.1562 - acc: 0.9355 - val_loss: 0.1549 - val_acc: 0.9364
# Epoch 7/10
# 4982178/4982178 [==============================] - 174s 35us/step - loss: 0.1498 - acc: 0.9385 - val_loss: 0.1482 - val_acc: 0.9394
# Epoch 8/10
# 4982178/4982178 [==============================] - 174s 35us/step - loss: 0.1446 - acc: 0.9405 - val_loss: 0.1432 - val_acc: 0.9416
# Epoch 9/10
# 4982178/4982178 [==============================] - 174s 35us/step - loss: 0.1402 - acc: 0.9427 - val_loss: 0.1430 - val_acc: 0.9414
# Epoch 10/10
# 4982178/4982178 [==============================] - 174s 35us/step - loss: 0.1363 - acc: 0.9443 - val_loss: 0.1432 - val_acc: 0.9420
# Training done
# Calculating score
# 2453910/2453910 [==============================] - 123s 50us/step
# (4982178, 4, 8, 8)
# Evaluated test loss: 0.14323990807848322
# Evaluated test accuracy: 0.9419571214916775
# Saving results to dir 429
# Saving history...
# Saving weights...
# Saving figures...
# Saving summary...
# Saving tensorboard logs...
# All done saving stuff!
#
#
#
# ==========================================================================================
# =                                                                                        =
# =                    Currently transfering first 1 layers, out of 8                      =
# =                                                                                        =
# ==========================================================================================
#
#     ==================================================================================
#     =                                                                                =
#     =                Currently at run 1, out of 1                                   =
#     =                                                                                =
#     ==================================================================================
#
# Loading first 1 layers from results Results/107/weights.hdf5,
# - 1: Freezing layer <keras.layers.convolutional.Conv2D object at 0x7fb3d618a710>
# - 2: Resetting layer <keras.layers.convolutional.Conv2D object at 0x7fb3d6522d30>
# - 3: Resetting layer <keras.layers.convolutional.Conv2D object at 0x7fb3d65229b0>
# - 4: Resetting layer <keras.layers.convolutional.Conv2D object at 0x7fb3d65222b0>
# - 5: Resetting layer <keras.layers.convolutional.Conv2D object at 0x7fb03f7498d0>
# - 6: Resetting layer <keras.layers.convolutional.Conv2D object at 0x7fb03f76f198>
# - 7: Resetting layer <keras.layers.convolutional.Conv2D object at 0x7fb03e6410b8>
# - 8: Skipping layer <keras.layers.core.Flatten object at 0x7fb03e67f438>
# - 9: Resetting layer <keras.layers.core.Dense object at 0x7fb03e2abda0>
# Save dir: Results/431/
# Creating save dir
# Done generating results dir Results/431/
# Train on 4982178 samples, validate on 2453910 samples
# Epoch 1/10
# 4982178/4982178 [==============================] - 161s 32us/step - loss: 0.3128 - acc: 0.8596 - val_loss: 0.2021 - val_acc: 0.9143
# Epoch 2/10
# 4982178/4982178 [==============================] - 163s 33us/step - loss: 0.1778 - acc: 0.9246 - val_loss: 0.1612 - val_acc: 0.9316
# Epoch 3/10
# 4982178/4982178 [==============================] - 162s 33us/step - loss: 0.1506 - acc: 0.9371 - val_loss: 0.1493 - val_acc: 0.9386
# Epoch 4/10
# 4982178/4982178 [==============================] - 162s 33us/step - loss: 0.1351 - acc: 0.9442 - val_loss: 0.1320 - val_acc: 0.9461
# Epoch 5/10
# 4982178/4982178 [==============================] - 162s 32us/step - loss: 0.1246 - acc: 0.9489 - val_loss: 0.1227 - val_acc: 0.9499
# Epoch 6/10
# 4982178/4982178 [==============================] - 162s 33us/step - loss: 0.1167 - acc: 0.9524 - val_loss: 0.1195 - val_acc: 0.9515
# Epoch 7/10
# 4982178/4982178 [==============================] - 162s 33us/step - loss: 0.1108 - acc: 0.9549 - val_loss: 0.1122 - val_acc: 0.9544
# Epoch 8/10
# 4982178/4982178 [==============================] - 162s 33us/step - loss: 0.1059 - acc: 0.9573 - val_loss: 0.1090 - val_acc: 0.9557
# Epoch 9/10
# 4982178/4982178 [==============================] - 162s 33us/step - loss: 0.1017 - acc: 0.9591 - val_loss: 0.1071 - val_acc: 0.9574
# Epoch 10/10
# 4982178/4982178 [==============================] - 162s 33us/step - loss: 0.0983 - acc: 0.9606 - val_loss: 0.1053 - val_acc: 0.9578
# Training done
# Calculating score
# 2453910/2453910 [==============================] - 125s 51us/step
# (4982178, 4, 8, 8)
# Evaluated test loss: 0.10530987611782423
# Evaluated test accuracy: 0.9578366769767432
# Saving results to dir 431
# Saving history...
# Saving weights...
# Saving figures...
# Saving summary...
# Saving tensorboard logs...
# All done saving stuff!
#
#
#
# ==========================================================================================
# =                                                                                        =
# =                    Currently transfering first 2 layers, out of 8                      =
# =                                                                                        =
# ==========================================================================================
#
#     ==================================================================================
#     =                                                                                =
#     =                Currently at run 1, out of 1                                   =
#     =                                                                                =
#     ==================================================================================
#
# Loading first 2 layers from results Results/107/weights.hdf5,
# - 1: Freezing layer <keras.layers.convolutional.Conv2D object at 0x7fb3d618a710>
# - 2: Freezing layer <keras.layers.convolutional.Conv2D object at 0x7fb3d6522d30>
# - 3: Resetting layer <keras.layers.convolutional.Conv2D object at 0x7fb3d65229b0>
# - 4: Resetting layer <keras.layers.convolutional.Conv2D object at 0x7fb3d65222b0>
# - 5: Resetting layer <keras.layers.convolutional.Conv2D object at 0x7fb03f7498d0>
# - 6: Resetting layer <keras.layers.convolutional.Conv2D object at 0x7fb03f76f198>
# - 7: Resetting layer <keras.layers.convolutional.Conv2D object at 0x7fb03e6410b8>
# - 8: Skipping layer <keras.layers.core.Flatten object at 0x7fb03e67f438>
# - 9: Resetting layer <keras.layers.core.Dense object at 0x7fb03e2abda0>
# Save dir: Results/433/
# Creating save dir
# Done generating results dir Results/433/
# Train on 4982178 samples, validate on 2453910 samples
# Epoch 1/10
# 4982178/4982178 [==============================] - 150s 30us/step - loss: 0.3307 - acc: 0.8512 - val_loss: 0.2155 - val_acc: 0.9086
# Epoch 2/10
# 4982178/4982178 [==============================] - 151s 30us/step - loss: 0.1886 - acc: 0.9197 - val_loss: 0.1699 - val_acc: 0.9281
# Epoch 3/10
# 4982178/4982178 [==============================] - 151s 30us/step - loss: 0.1577 - acc: 0.9338 - val_loss: 0.1463 - val_acc: 0.9392
# Epoch 4/10
# 4982178/4982178 [==============================] - 150s 30us/step - loss: 0.1392 - acc: 0.9425 - val_loss: 0.1473 - val_acc: 0.9394
# Epoch 5/10
# 4982178/4982178 [==============================] - 150s 30us/step - loss: 0.1270 - acc: 0.9481 - val_loss: 0.1321 - val_acc: 0.9455
# Epoch 6/10
# 4982178/4982178 [==============================] - 152s 30us/step - loss: 0.1183 - acc: 0.9520 - val_loss: 0.1197 - val_acc: 0.9518
# Epoch 7/10
# 4982178/4982178 [==============================] - 150s 30us/step - loss: 0.1117 - acc: 0.9550 - val_loss: 0.1248 - val_acc: 0.9505
# Epoch 8/10
# 4982178/4982178 [==============================] - 150s 30us/step - loss: 0.1062 - acc: 0.9573 - val_loss: 0.1072 - val_acc: 0.9566
# Epoch 9/10
# 4982178/4982178 [==============================] - 150s 30us/step - loss: 0.1019 - acc: 0.9592 - val_loss: 0.1036 - val_acc: 0.9586
# Epoch 10/10
# 4982178/4982178 [==============================] - 150s 30us/step - loss: 0.0983 - acc: 0.9608 - val_loss: 0.0996 - val_acc: 0.9606
# Training done
# Calculating score
# 2453910/2453910 [==============================] - 125s 51us/step
# (4982178, 4, 8, 8)
# Evaluated test loss: 0.09956274272241336
# Evaluated test accuracy: 0.9605731261537709
# Saving results to dir 433
# Saving history...
# Saving weights...
# Saving figures...
# Saving summary...
# Saving tensorboard logs...
# All done saving stuff!
#
#
#
# ==========================================================================================
# =                                                                                        =
# =                    Currently transfering first 3 layers, out of 8                      =
# =                                                                                        =
# ==========================================================================================
#
#     ==================================================================================
#     =                                                                                =
#     =                Currently at run 1, out of 1                                   =
#     =                                                                                =
#     ==================================================================================
#
# Loading first 3 layers from results Results/107/weights.hdf5,
# - 1: Freezing layer <keras.layers.convolutional.Conv2D object at 0x7fb3d618a710>
# - 2: Freezing layer <keras.layers.convolutional.Conv2D object at 0x7fb3d6522d30>
# - 3: Freezing layer <keras.layers.convolutional.Conv2D object at 0x7fb3d65229b0>
# - 4: Resetting layer <keras.layers.convolutional.Conv2D object at 0x7fb3d65222b0>
# - 5: Resetting layer <keras.layers.convolutional.Conv2D object at 0x7fb03f7498d0>
# - 6: Resetting layer <keras.layers.convolutional.Conv2D object at 0x7fb03f76f198>
# - 7: Resetting layer <keras.layers.convolutional.Conv2D object at 0x7fb03e6410b8>
# - 8: Skipping layer <keras.layers.core.Flatten object at 0x7fb03e67f438>
# - 9: Resetting layer <keras.layers.core.Dense object at 0x7fb03e2abda0>
# Save dir: Results/435/
# Creating save dir
# Done generating results dir Results/435/
# Train on 4982178 samples, validate on 2453910 samples
# Epoch 1/10
# 4982178/4982178 [==============================] - 138s 28us/step - loss: 0.2882 - acc: 0.8734 - val_loss: 0.2084 - val_acc: 0.9115
# Epoch 2/10
# 4982178/4982178 [==============================] - 139s 28us/step - loss: 0.1842 - acc: 0.9218 - val_loss: 0.1740 - val_acc: 0.9275
# Epoch 3/10
# 4982178/4982178 [==============================] - 139s 28us/step - loss: 0.1592 - acc: 0.9335 - val_loss: 0.1532 - val_acc: 0.9367
# Epoch 4/10
# 4982178/4982178 [==============================] - 139s 28us/step - loss: 0.1444 - acc: 0.9402 - val_loss: 0.1392 - val_acc: 0.9425
# Epoch 5/10
# 4982178/4982178 [==============================] - 138s 28us/step - loss: 0.1350 - acc: 0.9446 - val_loss: 0.1321 - val_acc: 0.9460
# Epoch 6/10
# 4982178/4982178 [==============================] - 138s 28us/step - loss: 0.1282 - acc: 0.9476 - val_loss: 0.1262 - val_acc: 0.9481
# Epoch 7/10
# 4982178/4982178 [==============================] - 139s 28us/step - loss: 0.1227 - acc: 0.9500 - val_loss: 0.1271 - val_acc: 0.9486
# Epoch 8/10
# 4982178/4982178 [==============================] - 138s 28us/step - loss: 0.1181 - acc: 0.9521 - val_loss: 0.1193 - val_acc: 0.9516
# Epoch 9/10
# 4982178/4982178 [==============================] - 138s 28us/step - loss: 0.1144 - acc: 0.9537 - val_loss: 0.1184 - val_acc: 0.9520
# Epoch 10/10
# 4982178/4982178 [==============================] - 139s 28us/step - loss: 0.1108 - acc: 0.9552 - val_loss: 0.1162 - val_acc: 0.9530
# Training done
# Calculating score
# 2453910/2453910 [==============================] - 127s 52us/step
# (4982178, 4, 8, 8)
# Evaluated test loss: 0.11621469594654346
# Evaluated test accuracy: 0.9530039814011109
# Saving results to dir 435
# Saving history...
# Saving weights...
# Saving figures...
# Saving summary...
# Saving tensorboard logs...
# All done saving stuff!
#
#
#
# ==========================================================================================
# =                                                                                        =
# =                    Currently transfering first 4 layers, out of 8                      =
# =                                                                                        =
# ==========================================================================================
#
#     ==================================================================================
#     =                                                                                =
#     =                Currently at run 1, out of 1                                   =
#     =                                                                                =
#     ==================================================================================
#
# Loading first 4 layers from results Results/107/weights.hdf5,
# - 1: Freezing layer <keras.layers.convolutional.Conv2D object at 0x7fb3d618a710>
# - 2: Freezing layer <keras.layers.convolutional.Conv2D object at 0x7fb3d6522d30>
# - 3: Freezing layer <keras.layers.convolutional.Conv2D object at 0x7fb3d65229b0>
# - 4: Freezing layer <keras.layers.convolutional.Conv2D object at 0x7fb3d65222b0>
# - 5: Resetting layer <keras.layers.convolutional.Conv2D object at 0x7fb03f7498d0>
# - 6: Resetting layer <keras.layers.convolutional.Conv2D object at 0x7fb03f76f198>
# - 7: Resetting layer <keras.layers.convolutional.Conv2D object at 0x7fb03e6410b8>
# - 8: Skipping layer <keras.layers.core.Flatten object at 0x7fb03e67f438>
# - 9: Resetting layer <keras.layers.core.Dense object at 0x7fb03e2abda0>
# Save dir: Results/437/
# Creating save dir
# Done generating results dir Results/437/
# Train on 4982178 samples, validate on 2453910 samples
# Epoch 1/10
# 4982178/4982178 [==============================] - 126s 25us/step - loss: 0.2415 - acc: 0.8960 - val_loss: 0.1773 - val_acc: 0.9258
# Epoch 2/10
# 4982178/4982178 [==============================] - 126s 25us/step - loss: 0.1593 - acc: 0.9336 - val_loss: 0.1497 - val_acc: 0.9382
# Epoch 3/10
# 4982178/4982178 [==============================] - 126s 25us/step - loss: 0.1399 - acc: 0.9424 - val_loss: 0.1336 - val_acc: 0.9452
# Epoch 4/10
# 4982178/4982178 [==============================] - 126s 25us/step - loss: 0.1282 - acc: 0.9476 - val_loss: 0.1273 - val_acc: 0.9483
# Epoch 5/10
# 4982178/4982178 [==============================] - 126s 25us/step - loss: 0.1204 - acc: 0.9511 - val_loss: 0.1199 - val_acc: 0.9514
# Epoch 6/10
# 4982178/4982178 [==============================] - 126s 25us/step - loss: 0.1151 - acc: 0.9533 - val_loss: 0.1146 - val_acc: 0.9539
# Epoch 7/10
# 4982178/4982178 [==============================] - 126s 25us/step - loss: 0.1110 - acc: 0.9552 - val_loss: 0.1152 - val_acc: 0.9536
# Epoch 8/10
# 4982178/4982178 [==============================] - 126s 25us/step - loss: 0.1077 - acc: 0.9567 - val_loss: 0.1113 - val_acc: 0.9555
# Epoch 9/10
# 4982178/4982178 [==============================] - 126s 25us/step - loss: 0.1050 - acc: 0.9578 - val_loss: 0.1093 - val_acc: 0.9559
# Epoch 10/10
# 4982178/4982178 [==============================] - 125s 25us/step - loss: 0.1027 - acc: 0.9587 - val_loss: 0.1059 - val_acc: 0.9576
# Training done
# Calculating score
# 2453910/2453910 [==============================] - 127s 52us/step
# (4982178, 4, 8, 8)
# Evaluated test loss: 0.10586388962375048
# Evaluated test accuracy: 0.9576035795933836
# Saving results to dir 437
# Saving history...
# Saving weights...
# Saving figures...
# Saving summary...
# Saving tensorboard logs...
# All done saving stuff!
#
#
#
# ==========================================================================================
# =                                                                                        =
# =                    Currently transfering first 5 layers, out of 8                      =
# =                                                                                        =
# ==========================================================================================
#
#     ==================================================================================
#     =                                                                                =
#     =                Currently at run 1, out of 1                                   =
#     =                                                                                =
#     ==================================================================================
#
# Loading first 5 layers from results Results/107/weights.hdf5,
# - 1: Freezing layer <keras.layers.convolutional.Conv2D object at 0x7fb3d618a710>
# - 2: Freezing layer <keras.layers.convolutional.Conv2D object at 0x7fb3d6522d30>
# - 3: Freezing layer <keras.layers.convolutional.Conv2D object at 0x7fb3d65229b0>
# - 4: Freezing layer <keras.layers.convolutional.Conv2D object at 0x7fb3d65222b0>
# - 5: Freezing layer <keras.layers.convolutional.Conv2D object at 0x7fb03f7498d0>
# - 6: Resetting layer <keras.layers.convolutional.Conv2D object at 0x7fb03f76f198>
# - 7: Resetting layer <keras.layers.convolutional.Conv2D object at 0x7fb03e6410b8>
# - 8: Skipping layer <keras.layers.core.Flatten object at 0x7fb03e67f438>
# - 9: Resetting layer <keras.layers.core.Dense object at 0x7fb03e2abda0>
# Save dir: Results/438/
# Creating save dir
# Done generating results dir Results/438/
# Train on 4982178 samples, validate on 2453910 samples
# Epoch 1/10
# 4982178/4982178 [==============================] - 116s 23us/step - loss: 0.1837 - acc: 0.9234 - val_loss: 0.1379 - val_acc: 0.9436
# Epoch 2/10
# 4982178/4982178 [==============================] - 115s 23us/step - loss: 0.1261 - acc: 0.9491 - val_loss: 0.1192 - val_acc: 0.9521
# Epoch 3/10
# 4982178/4982178 [==============================] - 116s 23us/step - loss: 0.1114 - acc: 0.9555 - val_loss: 0.1074 - val_acc: 0.9571
# Epoch 4/10
# 4982178/4982178 [==============================] - 116s 23us/step - loss: 0.1030 - acc: 0.9591 - val_loss: 0.1074 - val_acc: 0.9572
# Epoch 5/10
# 4982178/4982178 [==============================] - 115s 23us/step - loss: 0.0974 - acc: 0.9614 - val_loss: 0.0995 - val_acc: 0.9605
# Epoch 6/10
# 4982178/4982178 [==============================] - 116s 23us/step - loss: 0.0935 - acc: 0.9630 - val_loss: 0.0961 - val_acc: 0.9619
# Epoch 7/10
# 4982178/4982178 [==============================] - 116s 23us/step - loss: 0.0903 - acc: 0.9643 - val_loss: 0.0919 - val_acc: 0.9638
# Epoch 8/10
# 4982178/4982178 [==============================] - 115s 23us/step - loss: 0.0877 - acc: 0.9656 - val_loss: 0.0906 - val_acc: 0.9643
# Epoch 9/10
# 4982178/4982178 [==============================] - 116s 23us/step - loss: 0.0855 - acc: 0.9664 - val_loss: 0.0889 - val_acc: 0.9652
# Epoch 10/10
# 4982178/4982178 [==============================] - 116s 23us/step - loss: 0.0836 - acc: 0.9672 - val_loss: 0.0865 - val_acc: 0.9661
# Training done
# Calculating score
# 2453910/2453910 [==============================] - 127s 52us/step
# (4982178, 4, 8, 8)
# Evaluated test loss: 0.0865397208730484
# Evaluated test accuracy: 0.9660545822788937
# Saving results to dir 438
# Saving history...
# Saving weights...
# Saving figures...
# Saving summary...
# Saving tensorboard logs...
# All done saving stuff!
#
#
#
# ==========================================================================================
# =                                                                                        =
# =                    Currently transfering first 6 layers, out of 8                      =
# =                                                                                        =
# ==========================================================================================
#
#     ==================================================================================
#     =                                                                                =
#     =                Currently at run 1, out of 1                                   =
#     =                                                                                =
#     ==================================================================================
#
# Loading first 6 layers from results Results/107/weights.hdf5,
# - 1: Freezing layer <keras.layers.convolutional.Conv2D object at 0x7fb3d618a710>
# - 2: Freezing layer <keras.layers.convolutional.Conv2D object at 0x7fb3d6522d30>
# - 3: Freezing layer <keras.layers.convolutional.Conv2D object at 0x7fb3d65229b0>
# - 4: Freezing layer <keras.layers.convolutional.Conv2D object at 0x7fb3d65222b0>
# - 5: Freezing layer <keras.layers.convolutional.Conv2D object at 0x7fb03f7498d0>
# - 6: Freezing layer <keras.layers.convolutional.Conv2D object at 0x7fb03f76f198>
# - 7: Resetting layer <keras.layers.convolutional.Conv2D object at 0x7fb03e6410b8>
# - 8: Skipping layer <keras.layers.core.Flatten object at 0x7fb03e67f438>
# - 9: Resetting layer <keras.layers.core.Dense object at 0x7fb03e2abda0>
# Save dir: Results/440/
# Creating save dir
# Done generating results dir Results/440/
# Train on 4982178 samples, validate on 2453910 samples
# Epoch 1/10
# 4982178/4982178 [==============================] - 104s 21us/step - loss: 0.1163 - acc: 0.9539 - val_loss: 0.0826 - val_acc: 0.9675
# Epoch 2/10
# 4982178/4982178 [==============================] - 104s 21us/step - loss: 0.0745 - acc: 0.9711 - val_loss: 0.0706 - val_acc: 0.9728
# Epoch 3/10
# 4982178/4982178 [==============================] - 104s 21us/step - loss: 0.0663 - acc: 0.9744 - val_loss: 0.0693 - val_acc: 0.9734
# Epoch 4/10
# 4982178/4982178 [==============================] - 104s 21us/step - loss: 0.0618 - acc: 0.9763 - val_loss: 0.0630 - val_acc: 0.9760
# Epoch 5/10
# 4982178/4982178 [==============================] - 104s 21us/step - loss: 0.0587 - acc: 0.9775 - val_loss: 0.0616 - val_acc: 0.9764
# Epoch 6/10
# 4982178/4982178 [==============================] - 104s 21us/step - loss: 0.0567 - acc: 0.9783 - val_loss: 0.0620 - val_acc: 0.9766
# Epoch 7/10
# 4982178/4982178 [==============================] - 104s 21us/step - loss: 0.0549 - acc: 0.9791 - val_loss: 0.0609 - val_acc: 0.9772
# Epoch 8/10
# 4982178/4982178 [==============================] - 104s 21us/step - loss: 0.0536 - acc: 0.9797 - val_loss: 0.0554 - val_acc: 0.9790
# Epoch 9/10
# 4982178/4982178 [==============================] - 104s 21us/step - loss: 0.0524 - acc: 0.9802 - val_loss: 0.0601 - val_acc: 0.9779
# Epoch 10/10
# 4982178/4982178 [==============================] - 104s 21us/step - loss: 0.0516 - acc: 0.9805 - val_loss: 0.0587 - val_acc: 0.9783
# Training done
# Calculating score
# 2453910/2453910 [==============================] - 128s 52us/step
# (4982178, 4, 8, 8)
# Evaluated test loss: 0.05874337154638988
# Evaluated test accuracy: 0.9782958625214454
# Saving results to dir 440
# Saving history...
# Saving weights...
# Saving figures...
# Saving summary...
# Saving tensorboard logs...
# All done saving stuff!
#
#
#
# ==========================================================================================
# =                                                                                        =
# =                    Currently transfering first 7 layers, out of 8                      =
# =                                                                                        =
# ==========================================================================================
#
#     ==================================================================================
#     =                                                                                =
#     =                Currently at run 1, out of 1                                   =
#     =                                                                                =
#     ==================================================================================
#
# Loading first 7 layers from results Results/107/weights.hdf5,
# - 1: Freezing layer <keras.layers.convolutional.Conv2D object at 0x7fb3d618a710>
# - 2: Freezing layer <keras.layers.convolutional.Conv2D object at 0x7fb3d6522d30>
# - 3: Freezing layer <keras.layers.convolutional.Conv2D object at 0x7fb3d65229b0>
# - 4: Freezing layer <keras.layers.convolutional.Conv2D object at 0x7fb3d65222b0>
# - 5: Freezing layer <keras.layers.convolutional.Conv2D object at 0x7fb03f7498d0>
# - 6: Freezing layer <keras.layers.convolutional.Conv2D object at 0x7fb03f76f198>
# - 7: Freezing layer <keras.layers.convolutional.Conv2D object at 0x7fb03e6410b8>
# - 8: Skipping layer <keras.layers.core.Flatten object at 0x7fb03e67f438>
# - 9: Resetting layer <keras.layers.core.Dense object at 0x7fb03e2abda0>
# Save dir: Results/442/
# Creating save dir
# Done generating results dir Results/442/
# Train on 4982178 samples, validate on 2453910 samples
# Epoch 1/10
# 4982178/4982178 [==============================] - 92s 18us/step - loss: 0.0354 - acc: 0.9872 - val_loss: 0.0285 - val_acc: 0.9896
# Epoch 2/10
# 4982178/4982178 [==============================] - 91s 18us/step - loss: 0.0285 - acc: 0.9897 - val_loss: 0.0286 - val_acc: 0.9899
# Epoch 3/10
# 4982178/4982178 [==============================] - 92s 18us/step - loss: 0.0287 - acc: 0.9899 - val_loss: 0.0282 - val_acc: 0.9901
# Epoch 4/10
# 4982178/4982178 [==============================] - 91s 18us/step - loss: 0.0288 - acc: 0.9900 - val_loss: 0.0293 - val_acc: 0.9898
# Epoch 5/10
# 4982178/4982178 [==============================] - 92s 18us/step - loss: 0.0289 - acc: 0.9900 - val_loss: 0.0286 - val_acc: 0.9901
# Epoch 6/10
# 4982178/4982178 [==============================] - 91s 18us/step - loss: 0.0291 - acc: 0.9900 - val_loss: 0.0292 - val_acc: 0.9900
# Epoch 7/10
# 4982178/4982178 [==============================] - 92s 18us/step - loss: 0.0291 - acc: 0.9901 - val_loss: 0.0290 - val_acc: 0.9901
# Epoch 8/10
# 4982178/4982178 [==============================] - 91s 18us/step - loss: 0.0292 - acc: 0.9900 - val_loss: 0.0289 - val_acc: 0.9901
# Epoch 9/10
# 4982178/4982178 [==============================] - 92s 18us/step - loss: 0.0292 - acc: 0.9901 - val_loss: 0.0297 - val_acc: 0.9898
# Epoch 10/10
# 4982178/4982178 [==============================] - 91s 18us/step - loss: 0.0293 - acc: 0.9901 - val_loss: 0.0293 - val_acc: 0.9900
# Training done
# Calculating score
# 2453910/2453910 [==============================] - 128s 52us/step
# (4982178, 4, 8, 8)
# Evaluated test loss: 0.029314483797719122
# Evaluated test accuracy: 0.9899980031867509
# Saving results to dir 442
# Saving history...
# Saving weights...
# Saving figures...
# Saving summary...
# Saving tensorboard logs...
# All done saving stuff!
#
#
#
# ==========================================================================================
# =                                                                                        =
# =                    Currently transfering first 8 layers, out of 8                      =
# =                                                                                        =
# ==========================================================================================
#
#     ==================================================================================
#     =                                                                                =
#     =                Currently at run 1, out of 1                                   =
#     =                                                                                =
#     ==================================================================================
#
# Loading first 9 layers from results Results/107/weights.hdf5,
# - 1: Freezing layer <keras.layers.convolutional.Conv2D object at 0x7fb3d618a710>
# - 2: Freezing layer <keras.layers.convolutional.Conv2D object at 0x7fb3d6522d30>
# - 3: Freezing layer <keras.layers.convolutional.Conv2D object at 0x7fb3d65229b0>
# - 4: Freezing layer <keras.layers.convolutional.Conv2D object at 0x7fb3d65222b0>
# - 5: Freezing layer <keras.layers.convolutional.Conv2D object at 0x7fb03f7498d0>
# - 6: Freezing layer <keras.layers.convolutional.Conv2D object at 0x7fb03f76f198>
# - 7: Freezing layer <keras.layers.convolutional.Conv2D object at 0x7fb03e6410b8>
# - 8: Skipping layer <keras.layers.core.Flatten object at 0x7fb03e67f438>
# - 9: Freezing layer <keras.layers.core.Dense object at 0x7fb03e2abda0>
# Save dir: Results/443/
# Creating save dir
# Done generating results dir Results/443/
# Train on 4982178 samples, validate on 2453910 samples
# Epoch 1/10
# 4982178/4982178 [==============================] - 69s 14us/step - loss: 0.0359 - acc: 0.9885 - val_loss: 0.0355 - val_acc: 0.9885
# Epoch 2/10
# 4982178/4982178 [==============================] - 69s 14us/step - loss: 0.0359 - acc: 0.9885 - val_loss: 0.0355 - val_acc: 0.9885
# Epoch 3/10
# 4982178/4982178 [==============================] - 68s 14us/step - loss: 0.0359 - acc: 0.9885 - val_loss: 0.0355 - val_acc: 0.9885
# Epoch 4/10
# 4982178/4982178 [==============================] - 69s 14us/step - loss: 0.0359 - acc: 0.9885 - val_loss: 0.0355 - val_acc: 0.9885
# Epoch 5/10
# 4982178/4982178 [==============================] - 69s 14us/step - loss: 0.0359 - acc: 0.9885 - val_loss: 0.0355 - val_acc: 0.9885
# Epoch 6/10
# 4982178/4982178 [==============================] - 69s 14us/step - loss: 0.0359 - acc: 0.9885 - val_loss: 0.0355 - val_acc: 0.9885
# Epoch 7/10
# 4982178/4982178 [==============================] - 68s 14us/step - loss: 0.0359 - acc: 0.9885 - val_loss: 0.0355 - val_acc: 0.9885
# Epoch 8/10
# 4982178/4982178 [==============================] - 68s 14us/step - loss: 0.0359 - acc: 0.9885 - val_loss: 0.0355 - val_acc: 0.9885
# Epoch 9/10
# 4982178/4982178 [==============================] - 69s 14us/step - loss: 0.0359 - acc: 0.9885 - val_loss: 0.0355 - val_acc: 0.9885
# Epoch 10/10
# 4982178/4982178 [==============================] - 68s 14us/step - loss: 0.0359 - acc: 0.9885 - val_loss: 0.0355 - val_acc: 0.9885
# Training done
# Calculating score
# 2453910/2453910 [==============================] - 129s 52us/step
# (4982178, 4, 8, 8)
# Evaluated test loss: 0.03550400890796145
# Evaluated test accuracy: 0.9884906129401648
# Saving results to dir 443
# Saving history...
# Saving weights...
# Saving figures...
# Saving summary...
# Saving tensorboard logs...
# All done saving stuff!
#
#  Final Results: [0.9419571214916775, 0.9578366769767432, 0.9605731261537709, 0.9530039814011109, 0.9576035795933836, 0.9660545822788937, 0.9782958625214454, 0.9899980031867509, 0.9884906129401648]

# %% [markdown]
# # Experiment 3
# converging 3_8_4+

# %% [markdown]
# ### Exp 3 Paramters

# %%
sys.exit()
# Out:
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit
# /home/frimann/anaconda3/envs/endnetGpu8/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3275: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)

# %%
# %run -i 'arena.py'

# Parameters
sourceNet = '103' # trained on 3pc from scratch
# sourceNet = '107' # trained on 4pc from scratch ######################## MODIFY
freeze = False                           ############################### MODIFY
epochs = 10
averageOver = 10
                          ############################### MODIFY
expDescrBaseName = "Converging 3n4plus - average over {} runs - {} epochs".format(str(freeze), averageOver, epochs)

saveEveryRun = False # save stuff in results dir
saveWeightsCheckpoints = False # save chkp in results dit
saveTensorboardLogs = False # save logs in ./logs dir
resID = '---NORESID---' # used when not saving data, but fitModel() still needs a resID

fractionOfDataToUse = 0.001
plotDuringTraining = False
loadWeights = False 
askForConfirmation = False

# stuff to save in bengioResults dir
resSaveFile = '3_8_4_plus_Converge'                          ############################### MODIFY
saveDir = 'bengioResults'
resSaveFile = resSaveFile + '-{}runAverage-{}epochs'.format(averageOver, epochs)
resSaveFileFullPath = saveDir + '/' + str(resSaveFile) + '.pkl' 
resSaveFileAllRuns = resSaveFile + '-allRuns'.format(averageOver, epochs)
resSaveFileAllRunsFullPath = saveDir + '/' + str(resSaveFileAllRuns) + '.pkl' 
resSaveFileThisRun = resSaveFile + '-thisRun'.format(averageOver, epochs)
resSaveFileThisRunFullPath = saveDir + '/' + str(resSaveFileThisRun) + '.pkl'

# %% [markdown]
# ### Create model and load data

# %%
# prepare save file
if not os.path.exists(resSaveFileFullPath):
    print("Save file doesn't exists, creating...\n")
    save_obj(saveDir, resSaveFile, [])
else:
    print("Save file exists...\n")
    
if not os.path.exists(resSaveFileAllRunsFullPath):
    print("Save file for all runs doesn't exists, creating...\n")
    save_obj(saveDir, resSaveFileAllRuns, [])
else:
    print("Save file for all runs exists...\n")

if not os.path.exists(resSaveFileThisRunFullPath):
    print("Save file for this run doesn't exists, creating...\n")
    save_obj(saveDir, resSaveFileThisRun, [])
else:
    print("Save file for this run exists...\n")

# load data
X_train, X_test, y_train, y_test = loadData(randomState = None)

# create model
model, nnStr = createModel()
layersCount = len(model.layers)

# load old results
results = load_obj(saveDir, resSaveFile)
resultsAllRuns = load_obj(saveDir, resSaveFileAllRuns)
resultsThisRun = load_obj(saveDir, resSaveFileThisRun)

# initialize variables wrt old results
startTrainingAtLayer = len(results)
startTrainingAtLayer = 7
print("\nStarting/restarting TL at {} transfered layers".format(startTrainingAtLayer))
startThisRunAt = len(resultsThisRun)
print("\nStarting/restarting TL at average {}".format(startTrainingAtLayer))

# %%
print(results)
print(resultsThisRun)
print(resultsAllRuns)

# %% [markdown]
# ### Train

# %%
# %run -i 'arena.py'

for copyFirstNLayers in range(startTrainingAtLayer, layersCount):
    print('\n\n')
    print('==========================================================================================')
    print('=                                                                                        =')
    print('=                    Currently transfering first {} layers, out of {}                      ='.format(copyFirstNLayers, layersCount - 1))
    print('=                                                                                        =')
    print('==========================================================================================')
    print()
    
    # check if we are at the flatten layer, and skip it if so
    if copyFirstNLayers == layersCount - 1:
        copyFirstNLayers += 1
        
    # train and average results
    accumulatedScore = np.sum(resultsThisRun)
#     resultsThisRun = []
    for a in range(startThisRunAt,averageOver):
        print('    ==================================================================================')
        print('    =                                                                                =')
        print('    =                Currently at run {}, out of {}                                   ='.format(a+1,averageOver))
        print('    =                                                                                =')
        print('    ==================================================================================')
        print()
        
        # set experement description test
        expDescr = expDescrBaseName + '__copyLayers_{}__average_{}_of_{}'.format(copyFirstNLayers, a+1, averageOver)
        
        # save current averagePosition to tmp file
        with open(saveDir + '/' + str(resSaveFile) + '_currentPosition.txt','w') as file:
            if copyFirstNLayers == layersCount:
                location = copyFirstNLayers - 1
            else:
                location = copyFirstNLayers 
            file.write('Layers Transfered: {} out of {} \nInner avg loop position: {} out of {}'.format(location, layersCount-1, a+1, averageOver))         
            
        # load Model layers
        model = loadNFirstLayers(model, sourceNet, copyFirstNLayers , freeze)

        # Prepare save dir
        if saveEveryRun:
            resID = genNextResultsDir(model)

        # train
        fitHistory, logDir = trainModel(resID, model, saveWeightsCheckpoints, saveTensorboardLogs)

        # score and save results
        score = calcScore(model)
        if saveEveryRun:
            saveTrainResults(resID, model, logDir, score, copyFirstNLayers)

        # update Return
        accumulatedScore += score[1]
        resultsThisRun.append(score[1])
        
        
        # save checkpoint
        dateTime = time.strftime('%Y-%m-%d-%H:%M:%S', time.localtime())
        
        src = saveDir + '/' + str(resSaveFileThisRun) + '.pkl'
        dest = saveDir + '/checkpoints/' + str(resSaveFileThisRun) + dateTime + '.pkl'
        if os.path.exists(src):
            shutil.move(src, dest)
            
        src = saveDir + '/' + str(resSaveFileThisRun) + '.txt'
        dest = saveDir + '/checkpoints/' + str(resSaveFileThisRun) + dateTime + '.txt'
        if os.path.exists(src):
            shutil.move(src, dest)
        
        # save results 
        save_obj(saveDir, resSaveFileThisRun, resultsThisRun)
        with open(saveDir + '/' + str(resSaveFileThisRun) + '.txt','w') as file:
            file.write(str(resultsThisRun))
            
    # append averaged results for one set of layers
    results.append(accumulatedScore/averageOver)
    resultsAllRuns.append(resultsThisRun)

    # save old results to checkpoints dir
    dateTime = time.strftime('%Y-%m-%d-%H:%M:%S', time.localtime())
    
    src = saveDir + '/' + str(resSaveFile) + '.txt'
    dest = saveDir + '/checkpoints/' + str(resSaveFile) + dateTime + '.txt'
    if os.path.exists(src):
        shutil.move(src, dest)
        
    src = saveDir + '/' + str(resSaveFile) + '.pkl'
    dest = saveDir + '/checkpoints/' + str(resSaveFile) + dateTime + '.pkl'
    if os.path.exists(src):
        shutil.move(src, dest)

    src = saveDir + '/' + str(resSaveFileAllRuns) + '.txt'
    dest = saveDir + '/checkpoints/' + str(resSaveFileAllRuns) + dateTime + '.txt'
    if os.path.exists(src):
        shutil.move(src, dest)
        
    src = saveDir + '/' + str(resSaveFileAllRuns) + '.pkl'
    dest = saveDir + '/checkpoints/' + str(resSaveFileAllRuns) + dateTime + '.pkl'
    if os.path.exists(src):
        shutil.move(src, dest)
        
    # save results 
    save_obj(saveDir, resSaveFile, results)
    with open(saveDir + '/' + str(resSaveFile) + '.txt','w') as file:
        file.write(str(results))
    
    save_obj(saveDir, resSaveFileAllRuns, resultsAllRuns)
    with open(saveDir + '/' + str(resSaveFileAllRuns) + '.txt','w') as file:
        file.write(str(resultsAllRuns))

    # to load:
    # results = load_obj('temp','3n4.txt')
    resultsThisRun = []
print('\n Final Results: {}'.format(results))

# %%
resultsThisRun
# save_ob('.','x',resultsThisRun)

# %% [markdown]
# # Experiment 0
# test batch size vs time vs validation valley location

# %% [markdown]
# ### Exp 0 Paramters

# %% [markdown]
# %run -i 'arena.py'
#
# # Parameters
# weightsSource = '103' # trained on 3pc from scratch
# # sourceNet = '103' # trained on 3pc from scratch
# # sourceNet = '107' # trained on 4pc from scratch
# # freeze = False
# epochs = 350
# expDescrBaseName = "Batch size test"
#
# saveEveryRun = True # save stuff in results dir
# saveWeightsCheckpoints = False # save chkp in results dit
# saveTensorboardLogs = True # save logs in ./logs dir
# # resID = '---NORESID---' # used when not saving data, but fitModel() still needs a resID
#
# fractionOfDataToUse = 1
# plotDuringTraining = False
# loadWeights = False
# loadCheckpointWeights = False
# askForConfirmation = False

# %% [markdown]
# ### Create model and load data

# %% [markdown]
# # load data
# X_train, X_test, y_train, y_test = loadData(randomState = None)

# %% [markdown]
# ### Train

# %% [markdown]
# %run -i 'arena.py'
#
# batches = [128, 1024]
# for batch_size in batches:
#
#     expDescr = expDescrBaseName + '_batchSize{}'.format(batch_size)
#
#     # create model
#     model, nnStr = createModel()
#
#     # Prepare save dir
#     if saveEveryRun:
#         resID = genNextResultsDir(model)
#
#     # train
#     fitHistory, logDir = trainModel(resID, model, saveWeightsCheckpoints, saveTensorboardLogs)
#
#     # score and save results
#     score = calcScore(model)
#     if saveEveryRun:
#         saveTrainResults(resID, model, logDir, score)
