# %% [markdown]
# # Which GPU to use

# %%
multiGPU = False
whichGPU = 0
 
# Select which GPU to use
if(multiGPU):
    from keras.utils.training_utils import multi_gpu_model
else:
    import os
    os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID"
    # The GPU id to use, usually either "0" or "1"
    os.environ["CUDA_VISIBLE_DEVICES"] = str(whichGPU)
    
# # Do other imports now...

# %% [markdown]
# # Load all the functions

# %%
# %run -i 'arena.py'
# Out:
# Using TensorFlow backend.

# %%
# %load_ext autoreload
# %autoreload 1
# %aimport arena
# %reload_ext autoreload

# %% [markdown]
# # TRAINING TEMPLATE CODE

# %%
# %reload_ext autoreload
##### TRAINING TEMPLATE CODE

##############################
#
#    PARAMETERS 
#
##############################
import math

# Experiment description
expDescr = "Experiment description text"

# What data to use
tableBase = '4PpKk'
convertStates = False
fractionOfDataToUse = 1 # [0,1]

# Interactive (just in general if one is asked for confirmations, set to False if on autopilot over night f.x.)
askForConfirmation = True

# Transfer Learning
loadWeights = False 
weightsSource = '024'
loadCheckpointWeights = False

# Plot during training
plotDuringTraining = True
compareResultsDuringTraining = False
compareWith = '013' # orginal net structure, trained from random on 4pc dataset


# NN parameters
# filters = [8,16,16,32,32]    #016:0.913  10kpm 2048:30                  8192:23:38% 32768:17:52% 
# filters = [8,16,32,64,128]   #005:0.952  50kpm 2048:37s    4096:28:50% 
# filters = [8,32,64,128,256]  #013:0.968 188kpm 2048:50s    4096:40s:61%             32768:46s:80% 65536:42s:99% 
# filters = [32,64,128,160,256]#014:0.974 388kpm 2048:3m:91% 
# filters = [16,32,64,128,128,128]#035:0.975 191kpm 2048:45s:50%/50% 2048:68s:78% 
# filters = [16,16,32,32,64,64,128] #054 70kpm
# filters = [16,16,32,32,64,64,128] #054 70kpm
filters = [16,32,32,64,128,128,128]
filterShape = [2,2,2,2,2,2,2]
batch_size = 256
epochs = 150
multiGPU = False
whichGPU = 0
# optimizer = 'Adam'
optimizer = 'Adadelta'
useBatchNorm = False

# Other paramters
confirmDirOverwrite = False
tPrintInterval = 0.5 # for print progress
yieldSize = 10000 # for load generator

### NO NEED TO MODIFY BELOW ###
# Generate dataset variables
fileName = tableBase + '.hdf5'
dataSetName = tableBase + '_onlyLegal'
if not convertStates: 
    dataSetName = tableBase + '_onlyLegal_fullStates'
dataSetWdlName = tableBase + '_Wdl_onlyLegal_3Values'

# Number of Pieces
nPi =  int(dataSetName[0])
nPa = nPi - 2
nWPa = math.ceil(nPa/2)

# Select which GPU to use
# if(multiGPU):
#     from keras.utils.training_utils import multi_gpu_model
# else:
#     import os
#     os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID"
#     # The GPU id to use, usually either "0" or "1"
#     os.environ["CUDA_VISIBLE_DEVICES"] = str(whichGPU)
    
# Other NN stuff
num_classes = 3
input_shape = (4,8,8)

# %%
# Train, evaluate and save 
# %reload_ext autoreload
model, nnStr = createModel()
# resID = genNextResultsDir(model)
# X_train, X_test, y_train, y_test = loadData()
# score = calcScoreBigData(model)
# score = calcScore(model)
# saveTrainResults(resID, model, logDir, score)
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 16, 7, 7)          272
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 15, 6, 32)         928
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 14, 5, 32)         4128
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 13, 4, 64)         8256
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 12, 3, 128)        32896
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 11, 2, 128)        65664
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 10, 1, 128)        65664
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 1280)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 3)                 3843
# =================================================================
# Total params: 181,651
# Trainable params: 181,651
# Non-trainable params: 0
# _________________________________________________________________
# Starting with random weights
# Done creating model

# %% [markdown]
# ### many batches

# %%
# Train and save with different paramters
X_train, X_test, y_train, y_test = loadData()

bs = [256,256,256,512,512,512,1024,1024,1024]

for batch_size in bs:
    expDescr = "Testing batch size effect for 70kpm network (7 CNN layers) {}bs".format(batch_size) 
    print("---------------------- batch size ", batch_size, '-------------------------------')
    model, nnStr = createModel()
    resID = genNextResultsDir(model)
    fitHistory, logDir = trainModel(resID, model)
    score = calcScore(model)
    saveTrainResults(resID, model, logDir)

# %% [markdown]
# # Bengio Template Code

# %%
# 3n4 noFreeze
# %run -i 'arena.py'

# Parameters
sourceNet = '103'
freeze = False
epochs = 20
resSaveFile = '3n4plus'

fractionOfDataToUse = 1
plotDuringTraining = False
loadWeights = False 
askForConfirmation = False
saveDir = 'bengioResults'

X_train, X_test, y_train, y_test = loadData()
model, nnStr = createModel()
results = []
currentAverage = 0
averageOver = 
layersCount = len(model.layers)

for copyFirstNLayers in range(layersCount + 1):
    if copyFirstNLayers != layersCount - 1:
        model = loadNFirstLayers(model, sourceNet, copyFirstNLayers , freeze)

        resID = genNextResultsDir(model)
        #add freeze and some tl parameters to save dir

        # train
        fitHistory, logDir = trainModel(resID, model)

        # score and save accuracy
        score = calcScore(model)
        saveTrainResults(resID, model, logDir, score, copyFirstNLayers)
        results.append(score[1])

        # save results incrementally to txt file
        save_obj(bengioResults, resSaveFile, results)
        with open(bengioResults + '/' + str(resSaveFile) + '.txt','w') as file:
            file.write(str(results))
            
        # to load:
        # results = load_obj('temp','3n4.txt')
print(results)
# Out:
# X_train shape: (4982178, 4, 8, 8)
# y_train shape: (4982178, 1)
# X_test shape: (2453910, 4, 8, 8)
# y_test shape: (2453910, 1)
# 4982178 train samples
# 2453910 test samples
# Done loading dataset
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_43 (Conv2D)           (None, 16, 7, 7)          272
# _________________________________________________________________
# conv2d_44 (Conv2D)           (None, 15, 6, 32)         928
# _________________________________________________________________
# conv2d_45 (Conv2D)           (None, 14, 5, 32)         4128
# _________________________________________________________________
# conv2d_46 (Conv2D)           (None, 13, 4, 64)         8256
# _________________________________________________________________
# conv2d_47 (Conv2D)           (None, 12, 3, 128)        32896
# _________________________________________________________________
# conv2d_48 (Conv2D)           (None, 11, 2, 128)        65664
# _________________________________________________________________
# conv2d_49 (Conv2D)           (None, 10, 1, 128)        65664
# _________________________________________________________________
# flatten_7 (Flatten)          (None, 1280)              0
# _________________________________________________________________
# dense_7 (Dense)              (None, 3)                 3843
# =================================================================
# Total params: 181,651
# Trainable params: 181,651
# Non-trainable params: 0
# _________________________________________________________________
# Starting with random weights
# Done creating model
# Loading weights from Results/103/weights.hdf5, keeping first 0 layers.
# - Resetting layer nr 1: <keras.layers.convolutional.Conv2D object at 0x7f38c87524a8>
# - Resetting layer nr 2: <keras.layers.convolutional.Conv2D object at 0x7f38c8752780>
# - Resetting layer nr 3: <keras.layers.convolutional.Conv2D object at 0x7f38ca8dbac8>
# - Resetting layer nr 4: <keras.layers.convolutional.Conv2D object at 0x7f3503f21048>
# - Resetting layer nr 5: <keras.layers.convolutional.Conv2D object at 0x7f38c7c5a358>
# - Resetting layer nr 6: <keras.layers.convolutional.Conv2D object at 0x7f3528071780>
# - Resetting layer nr 7: <keras.layers.convolutional.Conv2D object at 0x7f38c668bcf8>
# - Skipping layer nr 8: <keras.layers.core.Flatten object at 0x7f38c66912e8>
# - Resetting layer nr 9: <keras.layers.core.Dense object at 0x7f38c6691b00>
# Save dir: Results/177/
# Creating save dir
# Done generating results dir Results/177/
# Saving weights to Results/177/weightsCheckpoints/
# Train on 4982178 samples, validate on 2453910 samples
# Epoch 1/20
# 4980992/4982178 [============================>.] - ETA: 0s - loss: 0.2548 - acc: 0.8906
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~/projects/Endnet/mainCode/arena.py in <module>()
#      22
#      23         # train
# ---> 24         fitHistory, logDir = trainModel(resID, model)
#      25
#      26         # score and save accuracy
#
# ~/projects/Endnet/mainCode/arena.py in trainModel(resID, model)
#     488                                       keras.callbacks.TensorBoard(log_dir=logDir)],
#     489 #                          .format(resID,nPi, initWeightsId, kpm, int(time() - 1500000000)))],
# --> 490                            validation_data=(X_test, y_test))
#     491     print("Training done")
#     492     return fitHistory, logDir
#
# ~/anaconda3/envs/endnetGpu/lib/python3.5/site-packages/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, **kwargs)
#    1035                                         initial_epoch=initial_epoch,
#    1036                                         steps_per_epoch=steps_per_epoch,
# -> 1037                                         validation_steps=validation_steps)
#    1038
#    1039     def evaluate(self, x=None, y=None,
#
# ~/anaconda3/envs/endnetGpu/lib/python3.5/site-packages/keras/engine/training_arrays.py in fit_loop(model, f, ins, out_labels, batch_size, epochs, verbose, callbacks, val_f, val_ins, shuffle, callback_metrics, initial_epoch, steps_per_epoch, validation_steps)
#     210                         val_outs = test_loop(model, val_f, val_ins,
#     211                                              batch_size=batch_size,
# --> 212                                              verbose=0)
#     213                         val_outs = to_list(val_outs)
#     214                         # Same labels assumed.
#
# ~/anaconda3/envs/endnetGpu/lib/python3.5/site-packages/keras/engine/training_arrays.py in test_loop(model, f, ins, batch_size, verbose, steps)
#     390                 ins_batch[i] = ins_batch[i].toarray()
#     391
# --> 392             batch_outs = f(ins_batch)
#     393             if isinstance(batch_outs, list):
#     394                 if batch_index == 0:
#
# ~/anaconda3/envs/endnetGpu/lib/python3.5/site-packages/keras/backend/tensorflow_backend.py in __call__(self, inputs)
#    2664                 return self._legacy_call(inputs)
#    2665
# -> 2666             return self._call(inputs)
#    2667         else:
#    2668             if py_any(is_tensor(x) for x in inputs):
#
# ~/anaconda3/envs/endnetGpu/lib/python3.5/site-packages/keras/backend/tensorflow_backend.py in _call(self, inputs)
#    2633                                 feed_symbols,
#    2634                                 symbol_vals,
# -> 2635                                 session)
#    2636         fetched = self._callable_fn(*array_vals)
#    2637         return fetched[:len(self.outputs)]
#
# ~/anaconda3/envs/endnetGpu/lib/python3.5/site-packages/keras/backend/tensorflow_backend.py in _make_callable(self, feed_arrays, feed_symbols, symbol_vals, session)
#    2585         callable_opts.target.append(self.updates_op.name)
#    2586         # Create callable.
# -> 2587         callable_fn = session._make_callable_from_options(callable_opts)
#    2588         # Cache parameters corresponding to the generated callable, so that
#    2589         # we can detect future mismatches and refresh the callable.
#
# ~/anaconda3/envs/endnetGpu/lib/python3.5/site-packages/tensorflow/python/client/session.py in _make_callable_from_options(self, callable_options)
#    1412     """
#    1413     self._extend_graph()
# -> 1414     return BaseSession._Callable(self, callable_options)
#    1415
#    1416
#
# ~/anaconda3/envs/endnetGpu/lib/python3.5/site-packages/tensorflow/python/client/session.py in __init__(self, session, callable_options)
#    1366         with errors.raise_exception_on_not_ok_status() as status:
#    1367           self._handle = tf_session.TF_SessionMakeCallable(
# -> 1368               session._session, options_ptr, status)
#    1369       finally:
#    1370         tf_session.TF_DeleteBuffer(options_ptr)
#
# KeyboardInterrupt:

# %% [markdown]
# # Plot bengio results

# %%
# plot Bengio 

# load results
resSaveFile = '3n4'
saveDir = 'bengioResults'
acc3n4 = load_obj(saveDir,resSaveFile)

resSaveFile = '3n4plus'
saveDir = 'bengioResults'
acc3n4plus = load_obj(saveDir,resSaveFile)


# plot results
AnB = acc3n4
AnBplus = acc3n4plus
x = [i for i in range(len(AnB))]
fig = plt.figure(figsize=(10,7))
ax = fig.add_subplot(111)
ax.plot(x,AnB, label = '3n4', linewidth = 1)
ax.plot(x,AnBplus, label = '3n4plus', linewidth = 1)
ax.legend()
ax.grid(True)

# %% [markdown]
# # Calc Bengio-ish TL and average

# %%
# 3n4 no freeze and average
# %run -i 'arena.py'

# Parameters
sourceNet = '103' # trained on 3pc from scratch
# sourceNet = '107' # trained on 4pc from scratch
freeze = False
resSaveFile = '3n4nofreeze'
epochs = 10
averageOver = 10
expDescr = "Bengio 3n4 - no freeze = {} - average over {} runs".format(str(freeze), averageOver)

saveEveryRun = True # save stuff in results dir
saveWeightsCheckpoints = True # save chkp in results dit
saveTensorboardLogs = True # save logs in ./logs dir
resSaveFile = resSaveFile + '-{} run average'.format(averageOver)
fractionOfDataToUse = 1
plotDuringTraining = False
loadWeights = False 
askForConfirmation = False
saveDir = 'bengioResults'

X_train, X_test, y_train, y_test = loadData()
model, nnStr = createModel()
results = []
accumulatedScore = 0
layersCount = len(model.layers)

for copyFirstNLayers in range(layersCount + 1):
    print('=========== At layer {} of {} ==========='.format(copyFirstNLayers, layersCount - 1))
    if copyFirstNLayers != layersCount - 1:
        accumulatedScore = 0
        for a in range(averageOver):
            model = loadNFirstLayers(model, sourceNet, copyFirstNLayers , freeze)

            if saveEveryRun:
                resID = genNextResultsDir(model)
                #add freeze and some tl parameters to save dir

            # train
            fitHistory, logDir = trainModel(resID, model, saveWeightsCheckpoints, saveTensorboardLogs)

            # score and save accuracy
            score = calcScore(model)
            if saveEveryRun:
                saveTrainResults(resID, model, logDir, score, copyFirstNLayers)
            
            # update Return
            accumulatedScore += score[1]
        results.append(accumulatedScore/averageOver)

        # save results incrementally to txt file
        save_obj(saveDir, resSaveFile, results)
        with open(saveDir + '/' + str(resSaveFile) + '.txt','w') as file:
            file.write(str(results))
            
        # to load:
        # results = load_obj('temp','3n4.txt')
print('\n Final Results: {}'.format(results))
# Out:
# X_train shape: (4982178, 4, 8, 8)
# y_train shape: (4982178, 1)
# X_test shape: (2453910, 4, 8, 8)
# y_test shape: (2453910, 1)
# 4982178 train samples
# 2453910 test samples
# Done loading dataset
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_50 (Conv2D)           (None, 16, 7, 7)          272
# _________________________________________________________________
# conv2d_51 (Conv2D)           (None, 15, 6, 32)         928
# _________________________________________________________________
# conv2d_52 (Conv2D)           (None, 14, 5, 32)         4128
# _________________________________________________________________
# conv2d_53 (Conv2D)           (None, 13, 4, 64)         8256
# _________________________________________________________________
# conv2d_54 (Conv2D)           (None, 12, 3, 128)        32896
# _________________________________________________________________
# conv2d_55 (Conv2D)           (None, 11, 2, 128)        65664
# _________________________________________________________________
# conv2d_56 (Conv2D)           (None, 10, 1, 128)        65664
# _________________________________________________________________
# flatten_8 (Flatten)          (None, 1280)              0
# _________________________________________________________________
# dense_8 (Dense)              (None, 3)                 3843
# =================================================================
# Total params: 181,651
# Trainable params: 181,651
# Non-trainable params: 0
# _________________________________________________________________
# Starting with random weights
# Done creating model
# =========== At layer 0 of 8 ===========
# Loading first 0 layers from results Results/103/weights.hdf5,
# - Resetting layer nr 1: <keras.layers.convolutional.Conv2D object at 0x7fe536516c88>
# - Resetting layer nr 2: <keras.layers.convolutional.Conv2D object at 0x7fe536516be0>
# - Resetting layer nr 3: <keras.layers.convolutional.Conv2D object at 0x7fe4c2f084a8>
# - Resetting layer nr 4: <keras.layers.convolutional.Conv2D object at 0x7fe4c32c36a0>
# - Resetting layer nr 5: <keras.layers.convolutional.Conv2D object at 0x7fe4c2f275c0>
# - Resetting layer nr 6: <keras.layers.convolutional.Conv2D object at 0x7fe4c324a278>
# - Resetting layer nr 7: <keras.layers.convolutional.Conv2D object at 0x7fe4c32645f8>
# - Skipping layer nr 8: <keras.layers.core.Flatten object at 0x7fe4c327c4a8>
# - Resetting layer nr 9: <keras.layers.core.Dense object at 0x7fe4c327cef0>
# Save dir: Results/393/
# Creating save dir
# Done generating results dir Results/393/
# Saving weights to Results/393/weightsCheckpoints/
# Train on 4982178 samples, validate on 2453910 samples
# Epoch 1/10
# 4982178/4982178 [==============================] - 176s 35us/step - loss: 0.2745 - acc: 0.8815 - val_loss: 0.1857 - val_acc: 0.9216
#
# Epoch 00001: val_acc improved from -inf to 0.92158, saving model to Results/393/weightsCheckpoints/weights-checkp-001-0.922.hdf5
# Epoch 2/10
# 4982178/4982178 [==============================] - 164s 33us/step - loss: 0.1608 - acc: 0.9328 - val_loss: 0.1425 - val_acc: 0.9412
#
# Epoch 00002: val_acc improved from 0.92158 to 0.94123, saving model to Results/393/weightsCheckpoints/weights-checkp-002-0.941.hdf5
# Epoch 3/10
# 4982178/4982178 [==============================] - 164s 33us/step - loss: 0.1320 - acc: 0.9460 - val_loss: 0.1417 - val_acc: 0.9430
#
# Epoch 00003: val_acc improved from 0.94123 to 0.94295, saving model to Results/393/weightsCheckpoints/weights-checkp-003-0.943.hdf5
# Epoch 4/10
# 4982178/4982178 [==============================] - 165s 33us/step - loss: 0.1160 - acc: 0.9534 - val_loss: 0.1150 - val_acc: 0.9542
#
# Epoch 00004: val_acc improved from 0.94295 to 0.95418, saving model to Results/393/weightsCheckpoints/weights-checkp-004-0.954.hdf5
# Epoch 5/10
# 4982178/4982178 [==============================] - 165s 33us/step - loss: 0.1054 - acc: 0.9580 - val_loss: 0.1035 - val_acc: 0.9586
#
# Epoch 00005: val_acc improved from 0.95418 to 0.95857, saving model to Results/393/weightsCheckpoints/weights-checkp-005-0.959.hdf5
# Epoch 6/10
# 4982178/4982178 [==============================] - 166s 33us/step - loss: 0.0980 - acc: 0.9611 - val_loss: 0.1046 - val_acc: 0.9595
#
# Epoch 00006: val_acc improved from 0.95857 to 0.95955, saving model to Results/393/weightsCheckpoints/weights-checkp-006-0.960.hdf5
# Epoch 7/10
# 4982178/4982178 [==============================] - 177s 36us/step - loss: 0.0928 - acc: 0.9635 - val_loss: 0.0943 - val_acc: 0.9631
#
# Epoch 00007: val_acc improved from 0.95955 to 0.96312, saving model to Results/393/weightsCheckpoints/weights-checkp-007-0.963.hdf5
# Epoch 8/10
# 4982178/4982178 [==============================] - 177s 35us/step - loss: 0.0885 - acc: 0.9653 - val_loss: 0.0936 - val_acc: 0.9637
#
# Epoch 00008: val_acc improved from 0.96312 to 0.96368, saving model to Results/393/weightsCheckpoints/weights-checkp-008-0.964.hdf5
# Epoch 9/10
# 4982178/4982178 [==============================] - 177s 35us/step - loss: 0.0852 - acc: 0.9666 - val_loss: 0.0936 - val_acc: 0.9634
#
# Epoch 00009: val_acc did not improve from 0.96368
# Epoch 10/10
# 4982178/4982178 [==============================] - 177s 35us/step - loss: 0.0825 - acc: 0.9678 - val_loss: 0.0918 - val_acc: 0.9644
#
# Epoch 00010: val_acc improved from 0.96368 to 0.96441, saving model to Results/393/weightsCheckpoints/weights-checkp-010-0.964.hdf5
# Training done
# Calculating score
# 2453910/2453910 [==============================] - 133s 54us/step
# (4982178, 4, 8, 8)
# Evaluated test loss: 0.09183230114228917
# Evaluated test accuracy: 0.9644094526692676
# Saving results to dir 393
# Saving history...
# Saving weights...
# Saving figures...
# Saving summary...
# Saving tensorboard logs...
# All done saving stuff!
# Loading first 0 layers from results Results/103/weights.hdf5,
# - Resetting layer nr 1: <keras.layers.convolutional.Conv2D object at 0x7fe536516c88>
# - Resetting layer nr 2: <keras.layers.convolutional.Conv2D object at 0x7fe536516be0>
# - Resetting layer nr 3: <keras.layers.convolutional.Conv2D object at 0x7fe4c2f084a8>
# - Resetting layer nr 4: <keras.layers.convolutional.Conv2D object at 0x7fe4c32c36a0>
# - Resetting layer nr 5: <keras.layers.convolutional.Conv2D object at 0x7fe4c2f275c0>
# - Resetting layer nr 6: <keras.layers.convolutional.Conv2D object at 0x7fe4c324a278>
# - Resetting layer nr 7: <keras.layers.convolutional.Conv2D object at 0x7fe4c32645f8>
# - Skipping layer nr 8: <keras.layers.core.Flatten object at 0x7fe4c327c4a8>
# - Resetting layer nr 9: <keras.layers.core.Dense object at 0x7fe4c327cef0>
# Save dir: Results/395/
# Creating save dir
# Done generating results dir Results/395/
# Saving weights to Results/395/weightsCheckpoints/
# Train on 4982178 samples, validate on 2453910 samples
# Epoch 1/10
# 4982178/4982178 [==============================] - 178s 36us/step - loss: 0.2629 - acc: 0.8850 - val_loss: 0.1842 - val_acc: 0.9193
#
# Epoch 00001: val_acc improved from -inf to 0.91926, saving model to Results/395/weightsCheckpoints/weights-checkp-001-0.919.hdf5
# Epoch 2/10
# 4982178/4982178 [==============================] - 178s 36us/step - loss: 0.1580 - acc: 0.9330 - val_loss: 0.1493 - val_acc: 0.9374
#
# Epoch 00002: val_acc improved from 0.91926 to 0.93736, saving model to Results/395/weightsCheckpoints/weights-checkp-002-0.937.hdf5
# Epoch 3/10
# 4982178/4982178 [==============================] - 179s 36us/step - loss: 0.1305 - acc: 0.9460 - val_loss: 0.1273 - val_acc: 0.9481
#
# Epoch 00003: val_acc improved from 0.93736 to 0.94806, saving model to Results/395/weightsCheckpoints/weights-checkp-003-0.948.hdf5
# Epoch 4/10
# 4982178/4982178 [==============================] - 179s 36us/step - loss: 0.1148 - acc: 0.9533 - val_loss: 0.1093 - val_acc: 0.9556
#
# Epoch 00004: val_acc improved from 0.94806 to 0.95561, saving model to Results/395/weightsCheckpoints/weights-checkp-004-0.956.hdf5
# Epoch 5/10
# 4982178/4982178 [==============================] - 179s 36us/step - loss: 0.1046 - acc: 0.9578 - val_loss: 0.1059 - val_acc: 0.9573
#
# Epoch 00005: val_acc improved from 0.95561 to 0.95727, saving model to Results/395/weightsCheckpoints/weights-checkp-005-0.957.hdf5
# Epoch 6/10
# 4982178/4982178 [==============================] - 179s 36us/step - loss: 0.0978 - acc: 0.9608 - val_loss: 0.1055 - val_acc: 0.9580
#
# Epoch 00006: val_acc improved from 0.95727 to 0.95800, saving model to Results/395/weightsCheckpoints/weights-checkp-006-0.958.hdf5
# Epoch 7/10
# 4982178/4982178 [==============================] - 179s 36us/step - loss: 0.0927 - acc: 0.9630 - val_loss: 0.1004 - val_acc: 0.9599
#
# Epoch 00007: val_acc improved from 0.95800 to 0.95992, saving model to Results/395/weightsCheckpoints/weights-checkp-007-0.960.hdf5
# Epoch 8/10
# 4982178/4982178 [==============================] - 179s 36us/step - loss: 0.0887 - acc: 0.9647 - val_loss: 0.0919 - val_acc: 0.9639
#
# Epoch 00008: val_acc improved from 0.95992 to 0.96389, saving model to Results/395/weightsCheckpoints/weights-checkp-008-0.964.hdf5
# Epoch 9/10
# 4982178/4982178 [==============================] - 179s 36us/step - loss: 0.0856 - acc: 0.9661 - val_loss: 0.0922 - val_acc: 0.9636
#
# Epoch 00009: val_acc did not improve from 0.96389
# Epoch 10/10
# 4982178/4982178 [==============================] - 179s 36us/step - loss: 0.0832 - acc: 0.9670 - val_loss: 0.0906 - val_acc: 0.9649
#
# Epoch 00010: val_acc improved from 0.96389 to 0.96487, saving model to Results/395/weightsCheckpoints/weights-checkp-010-0.965.hdf5
# Training done
# Calculating score
# 2453910/2453910 [==============================] - 133s 54us/step
# (4982178, 4, 8, 8)
# Evaluated test loss: 0.09060588230134917
# Evaluated test accuracy: 0.9648654596136762
# Saving results to dir 395
# Saving history...
# Saving weights...
# Saving figures...
# Saving summary...
# Saving tensorboard logs...
# All done saving stuff!
# Loading first 0 layers from results Results/103/weights.hdf5,
# - Resetting layer nr 1: <keras.layers.convolutional.Conv2D object at 0x7fe536516c88>
# - Resetting layer nr 2: <keras.layers.convolutional.Conv2D object at 0x7fe536516be0>
# - Resetting layer nr 3: <keras.layers.convolutional.Conv2D object at 0x7fe4c2f084a8>
# - Resetting layer nr 4: <keras.layers.convolutional.Conv2D object at 0x7fe4c32c36a0>
# - Resetting layer nr 5: <keras.layers.convolutional.Conv2D object at 0x7fe4c2f275c0>
# - Resetting layer nr 6: <keras.layers.convolutional.Conv2D object at 0x7fe4c324a278>
# - Resetting layer nr 7: <keras.layers.convolutional.Conv2D object at 0x7fe4c32645f8>
# - Skipping layer nr 8: <keras.layers.core.Flatten object at 0x7fe4c327c4a8>
# - Resetting layer nr 9: <keras.layers.core.Dense object at 0x7fe4c327cef0>
# Save dir: Results/397/
# Creating save dir
# Done generating results dir Results/397/
# Saving weights to Results/397/weightsCheckpoints/
# Train on 4982178 samples, validate on 2453910 samples
# Epoch 1/10
# 4982178/4982178 [==============================] - 179s 36us/step - loss: 0.2785 - acc: 0.8791 - val_loss: 0.1939 - val_acc: 0.9171
#
# Epoch 00001: val_acc improved from -inf to 0.91705, saving model to Results/397/weightsCheckpoints/weights-checkp-001-0.917.hdf5
# Epoch 2/10
# 4982178/4982178 [==============================] - 179s 36us/step - loss: 0.1669 - acc: 0.9299 - val_loss: 0.1489 - val_acc: 0.9377
#
# Epoch 00002: val_acc improved from 0.91705 to 0.93774, saving model to Results/397/weightsCheckpoints/weights-checkp-002-0.938.hdf5
# Epoch 3/10
# 4982178/4982178 [==============================] - 179s 36us/step - loss: 0.1391 - acc: 0.9423 - val_loss: 0.1304 - val_acc: 0.9460
#
# Epoch 00003: val_acc improved from 0.93774 to 0.94598, saving model to Results/397/weightsCheckpoints/weights-checkp-003-0.946.hdf5
# Epoch 4/10
# 4982178/4982178 [==============================] - 179s 36us/step - loss: 0.1220 - acc: 0.9501 - val_loss: 0.1220 - val_acc: 0.9501
#
# Epoch 00004: val_acc improved from 0.94598 to 0.95006, saving model to Results/397/weightsCheckpoints/weights-checkp-004-0.950.hdf5
# Epoch 5/10
# 4982178/4982178 [==============================] - 179s 36us/step - loss: 0.1106 - acc: 0.9551 - val_loss: 0.1128 - val_acc: 0.9542
#
# Epoch 00005: val_acc improved from 0.95006 to 0.95423, saving model to Results/397/weightsCheckpoints/weights-checkp-005-0.954.hdf5
# Epoch 6/10
# 4982178/4982178 [==============================] - 179s 36us/step - loss: 0.1023 - acc: 0.9589 - val_loss: 0.1058 - val_acc: 0.9574
#
# Epoch 00006: val_acc improved from 0.95423 to 0.95738, saving model to Results/397/weightsCheckpoints/weights-checkp-006-0.957.hdf5
# Epoch 7/10
# 4982178/4982178 [==============================] - 179s 36us/step - loss: 0.0964 - acc: 0.9614 - val_loss: 0.1134 - val_acc: 0.9554
#
# Epoch 00007: val_acc did not improve from 0.95738
# Epoch 8/10
# 4982178/4982178 [==============================] - 179s 36us/step - loss: 0.0917 - acc: 0.9636 - val_loss: 0.0952 - val_acc: 0.9620
#
# Epoch 00008: val_acc improved from 0.95738 to 0.96199, saving model to Results/397/weightsCheckpoints/weights-checkp-008-0.962.hdf5
# Epoch 9/10
# 4982178/4982178 [==============================] - 179s 36us/step - loss: 0.0877 - acc: 0.9651 - val_loss: 0.0926 - val_acc: 0.9637
#
# Epoch 00009: val_acc improved from 0.96199 to 0.96368, saving model to Results/397/weightsCheckpoints/weights-checkp-009-0.964.hdf5
# Epoch 10/10
# 4982178/4982178 [==============================] - 179s 36us/step - loss: 0.0844 - acc: 0.9666 - val_loss: 0.0890 - val_acc: 0.9649
#
# Epoch 00010: val_acc improved from 0.96368 to 0.96491, saving model to Results/397/weightsCheckpoints/weights-checkp-010-0.965.hdf5
# Training done
# Calculating score
# 2453910/2453910 [==============================] - 132s 54us/step
# (4982178, 4, 8, 8)
# Evaluated test loss: 0.08903123931316127
# Evaluated test accuracy: 0.9649143611626327
# Saving results to dir 397
# Saving history...
# Saving weights...
# Saving figures...
# Saving summary...
# Saving tensorboard logs...
# All done saving stuff!
# Loading first 0 layers from results Results/103/weights.hdf5,
# - Resetting layer nr 1: <keras.layers.convolutional.Conv2D object at 0x7fe536516c88>
# - Resetting layer nr 2: <keras.layers.convolutional.Conv2D object at 0x7fe536516be0>
# - Resetting layer nr 3: <keras.layers.convolutional.Conv2D object at 0x7fe4c2f084a8>
# - Resetting layer nr 4: <keras.layers.convolutional.Conv2D object at 0x7fe4c32c36a0>
# - Resetting layer nr 5: <keras.layers.convolutional.Conv2D object at 0x7fe4c2f275c0>
# - Resetting layer nr 6: <keras.layers.convolutional.Conv2D object at 0x7fe4c324a278>
# - Resetting layer nr 7: <keras.layers.convolutional.Conv2D object at 0x7fe4c32645f8>
# - Skipping layer nr 8: <keras.layers.core.Flatten object at 0x7fe4c327c4a8>
# - Resetting layer nr 9: <keras.layers.core.Dense object at 0x7fe4c327cef0>
# Save dir: Results/399/
# Creating save dir
# Done generating results dir Results/399/
# Saving weights to Results/399/weightsCheckpoints/
# Train on 4982178 samples, validate on 2453910 samples
# Epoch 1/10
# 4982178/4982178 [==============================] - 179s 36us/step - loss: 0.2650 - acc: 0.8850 - val_loss: 0.1763 - val_acc: 0.9243
#
# Epoch 00001: val_acc improved from -inf to 0.92425, saving model to Results/399/weightsCheckpoints/weights-checkp-001-0.924.hdf5
# Epoch 2/10
# 4982178/4982178 [==============================] - 179s 36us/step - loss: 0.1531 - acc: 0.9357 - val_loss: 0.1384 - val_acc: 0.9422
#
# Epoch 00002: val_acc improved from 0.92425 to 0.94217, saving model to Results/399/weightsCheckpoints/weights-checkp-002-0.942.hdf5
# Epoch 3/10
# 4982178/4982178 [==============================] - 179s 36us/step - loss: 0.1224 - acc: 0.9499 - val_loss: 0.1154 - val_acc: 0.9534
#
# Epoch 00003: val_acc improved from 0.94217 to 0.95335, saving model to Results/399/weightsCheckpoints/weights-checkp-003-0.953.hdf5
# Epoch 4/10
# 4982178/4982178 [==============================] - 179s 36us/step - loss: 0.1047 - acc: 0.9577 - val_loss: 0.1065 - val_acc: 0.9571
#
# Epoch 00004: val_acc improved from 0.95335 to 0.95714, saving model to Results/399/weightsCheckpoints/weights-checkp-004-0.957.hdf5
# Epoch 5/10
# 4982178/4982178 [==============================] - 179s 36us/step - loss: 0.0936 - acc: 0.9625 - val_loss: 0.0981 - val_acc: 0.9607
#
# Epoch 00005: val_acc improved from 0.95714 to 0.96074, saving model to Results/399/weightsCheckpoints/weights-checkp-005-0.961.hdf5
# Epoch 6/10
# 4982178/4982178 [==============================] - 179s 36us/step - loss: 0.0860 - acc: 0.9658 - val_loss: 0.0899 - val_acc: 0.9646
#
# Epoch 00006: val_acc improved from 0.96074 to 0.96462, saving model to Results/399/weightsCheckpoints/weights-checkp-006-0.965.hdf5
# Epoch 7/10
# 4982178/4982178 [==============================] - 179s 36us/step - loss: 0.0803 - acc: 0.9682 - val_loss: 0.0836 - val_acc: 0.9672
#
# Epoch 00007: val_acc improved from 0.96462 to 0.96719, saving model to Results/399/weightsCheckpoints/weights-checkp-007-0.967.hdf5
# Epoch 8/10
# 4982178/4982178 [==============================] - 179s 36us/step - loss: 0.0758 - acc: 0.9701 - val_loss: 0.0847 - val_acc: 0.9670
#
# Epoch 00008: val_acc did not improve from 0.96719
# Epoch 9/10
# 4982178/4982178 [==============================] - 179s 36us/step - loss: 0.0724 - acc: 0.9716 - val_loss: 0.0735 - val_acc: 0.9713
#
# Epoch 00009: val_acc improved from 0.96719 to 0.97127, saving model to Results/399/weightsCheckpoints/weights-checkp-009-0.971.hdf5
# Epoch 10/10
# 4982178/4982178 [==============================] - 179s 36us/step - loss: 0.0696 - acc: 0.9729 - val_loss: 0.0828 - val_acc: 0.9680
#
# Epoch 00010: val_acc did not improve from 0.97127
# Training done
# Calculating score
# 2453910/2453910 [==============================] - 132s 54us/step
# (4982178, 4, 8, 8)
# Evaluated test loss: 0.08279502100826637
# Evaluated test accuracy: 0.9680053465695955
# Saving results to dir 399
# Saving history...
# Saving weights...
# Saving figures...
# Saving summary...
# Saving tensorboard logs...
# All done saving stuff!
# Loading first 0 layers from results Results/103/weights.hdf5,
# - Resetting layer nr 1: <keras.layers.convolutional.Conv2D object at 0x7fe536516c88>
# - Resetting layer nr 2: <keras.layers.convolutional.Conv2D object at 0x7fe536516be0>
# - Resetting layer nr 3: <keras.layers.convolutional.Conv2D object at 0x7fe4c2f084a8>
# - Resetting layer nr 4: <keras.layers.convolutional.Conv2D object at 0x7fe4c32c36a0>
# - Resetting layer nr 5: <keras.layers.convolutional.Conv2D object at 0x7fe4c2f275c0>
# - Resetting layer nr 6: <keras.layers.convolutional.Conv2D object at 0x7fe4c324a278>
# - Resetting layer nr 7: <keras.layers.convolutional.Conv2D object at 0x7fe4c32645f8>
# - Skipping layer nr 8: <keras.layers.core.Flatten object at 0x7fe4c327c4a8>
# - Resetting layer nr 9: <keras.layers.core.Dense object at 0x7fe4c327cef0>
# Save dir: Results/401/
# Creating save dir
# Done generating results dir Results/401/
# Saving weights to Results/401/weightsCheckpoints/
# Train on 4982178 samples, validate on 2453910 samples
# Epoch 1/10
# 4982178/4982178 [==============================] - 179s 36us/step - loss: 0.2782 - acc: 0.8794 - val_loss: 0.1879 - val_acc: 0.9206
#
# Epoch 00001: val_acc improved from -inf to 0.92062, saving model to Results/401/weightsCheckpoints/weights-checkp-001-0.921.hdf5
# Epoch 2/10
# 4982178/4982178 [==============================] - 179s 36us/step - loss: 0.1606 - acc: 0.9331 - val_loss: 0.1418 - val_acc: 0.9419
#
# Epoch 00002: val_acc improved from 0.92062 to 0.94190, saving model to Results/401/weightsCheckpoints/weights-checkp-002-0.942.hdf5
# Epoch 3/10
# 4982178/4982178 [==============================] - 179s 36us/step - loss: 0.1304 - acc: 0.9466 - val_loss: 0.1280 - val_acc: 0.9480
#
# Epoch 00003: val_acc improved from 0.94190 to 0.94802, saving model to Results/401/weightsCheckpoints/weights-checkp-003-0.948.hdf5
# Epoch 4/10
# 4982178/4982178 [==============================] - 179s 36us/step - loss: 0.1142 - acc: 0.9536 - val_loss: 0.1161 - val_acc: 0.9529
#
# Epoch 00004: val_acc improved from 0.94802 to 0.95287, saving model to Results/401/weightsCheckpoints/weights-checkp-004-0.953.hdf5
# Epoch 5/10
# 4982178/4982178 [==============================] - 179s 36us/step - loss: 0.1039 - acc: 0.9580 - val_loss: 0.1064 - val_acc: 0.9572
#
# Epoch 00005: val_acc improved from 0.95287 to 0.95724, saving model to Results/401/weightsCheckpoints/weights-checkp-005-0.957.hdf5
# Epoch 6/10
# 4982178/4982178 [==============================] - 179s 36us/step - loss: 0.0964 - acc: 0.9613 - val_loss: 0.0946 - val_acc: 0.9623
#
# Epoch 00006: val_acc improved from 0.95724 to 0.96229, saving model to Results/401/weightsCheckpoints/weights-checkp-006-0.962.hdf5
# Epoch 7/10
# 4982178/4982178 [==============================] - 179s 36us/step - loss: 0.0908 - acc: 0.9638 - val_loss: 0.0941 - val_acc: 0.9626
#
# Epoch 00007: val_acc improved from 0.96229 to 0.96263, saving model to Results/401/weightsCheckpoints/weights-checkp-007-0.963.hdf5
# Epoch 8/10
# 4982178/4982178 [==============================] - 179s 36us/step - loss: 0.0865 - acc: 0.9656 - val_loss: 0.0911 - val_acc: 0.9641
#
# Epoch 00008: val_acc improved from 0.96263 to 0.96414, saving model to Results/401/weightsCheckpoints/weights-checkp-008-0.964.hdf5
# Epoch 9/10
# 4982178/4982178 [==============================] - 179s 36us/step - loss: 0.0828 - acc: 0.9671 - val_loss: 0.0881 - val_acc: 0.9652
#
# Epoch 00009: val_acc improved from 0.96414 to 0.96522, saving model to Results/401/weightsCheckpoints/weights-checkp-009-0.965.hdf5
# Epoch 10/10
# 4982178/4982178 [==============================] - 179s 36us/step - loss: 0.0796 - acc: 0.9685 - val_loss: 0.0885 - val_acc: 0.9654
#
# Epoch 00010: val_acc improved from 0.96522 to 0.96543, saving model to Results/401/weightsCheckpoints/weights-checkp-010-0.965.hdf5
# Training done
# Calculating score
# 2453910/2453910 [==============================] - 131s 54us/step
# (4982178, 4, 8, 8)
# Evaluated test loss: 0.08846246495116225
# Evaluated test accuracy: 0.9654270124006178
# Saving results to dir 401
# Saving history...
# Saving weights...
# Saving figures...
# Saving summary...
# Saving tensorboard logs...
# All done saving stuff!
# Loading first 0 layers from results Results/103/weights.hdf5,
# - Resetting layer nr 1: <keras.layers.convolutional.Conv2D object at 0x7fe536516c88>
# - Resetting layer nr 2: <keras.layers.convolutional.Conv2D object at 0x7fe536516be0>
# - Resetting layer nr 3: <keras.layers.convolutional.Conv2D object at 0x7fe4c2f084a8>
# - Resetting layer nr 4: <keras.layers.convolutional.Conv2D object at 0x7fe4c32c36a0>
# - Resetting layer nr 5: <keras.layers.convolutional.Conv2D object at 0x7fe4c2f275c0>
# - Resetting layer nr 6: <keras.layers.convolutional.Conv2D object at 0x7fe4c324a278>
# - Resetting layer nr 7: <keras.layers.convolutional.Conv2D object at 0x7fe4c32645f8>
# - Skipping layer nr 8: <keras.layers.core.Flatten object at 0x7fe4c327c4a8>
# - Resetting layer nr 9: <keras.layers.core.Dense object at 0x7fe4c327cef0>
# Save dir: Results/403/
# Creating save dir
# Done generating results dir Results/403/
# Saving weights to Results/403/weightsCheckpoints/
# Train on 4982178 samples, validate on 2453910 samples
# Epoch 1/10
# 4982178/4982178 [==============================] - 179s 36us/step - loss: 0.2845 - acc: 0.8762 - val_loss: 0.1906 - val_acc: 0.9190
#
# Epoch 00001: val_acc improved from -inf to 0.91905, saving model to Results/403/weightsCheckpoints/weights-checkp-001-0.919.hdf5
# Epoch 2/10
# 4982178/4982178 [==============================] - 177s 36us/step - loss: 0.1597 - acc: 0.9329 - val_loss: 0.1481 - val_acc: 0.9383
#
# Epoch 00002: val_acc improved from 0.91905 to 0.93831, saving model to Results/403/weightsCheckpoints/weights-checkp-002-0.938.hdf5
# Epoch 3/10
# 4982178/4982178 [==============================] - 178s 36us/step - loss: 0.1271 - acc: 0.9477 - val_loss: 0.1199 - val_acc: 0.9514
#
# Epoch 00003: val_acc improved from 0.93831 to 0.95141, saving model to Results/403/weightsCheckpoints/weights-checkp-003-0.951.hdf5
# Epoch 4/10
# 4982178/4982178 [==============================] - 178s 36us/step - loss: 0.1086 - acc: 0.9561 - val_loss: 0.1087 - val_acc: 0.9559
#
# Epoch 00004: val_acc improved from 0.95141 to 0.95586, saving model to Results/403/weightsCheckpoints/weights-checkp-004-0.956.hdf5
# Epoch 5/10
# 4982178/4982178 [==============================] - 178s 36us/step - loss: 0.0968 - acc: 0.9612 - val_loss: 0.0987 - val_acc: 0.9606
#
# Epoch 00005: val_acc improved from 0.95586 to 0.96057, saving model to Results/403/weightsCheckpoints/weights-checkp-005-0.961.hdf5
# Epoch 6/10
# 4982178/4982178 [==============================] - 178s 36us/step - loss: 0.0888 - acc: 0.9646 - val_loss: 0.0912 - val_acc: 0.9638
#
# Epoch 00006: val_acc improved from 0.96057 to 0.96384, saving model to Results/403/weightsCheckpoints/weights-checkp-006-0.964.hdf5
# Epoch 7/10
# 4982178/4982178 [==============================] - 178s 36us/step - loss: 0.0826 - acc: 0.9673 - val_loss: 0.0869 - val_acc: 0.9656
#
# Epoch 00007: val_acc improved from 0.96384 to 0.96559, saving model to Results/403/weightsCheckpoints/weights-checkp-007-0.966.hdf5
# Epoch 8/10
# 4982178/4982178 [==============================] - 179s 36us/step - loss: 0.0780 - acc: 0.9693 - val_loss: 0.0815 - val_acc: 0.9682
#
# Epoch 00008: val_acc improved from 0.96559 to 0.96815, saving model to Results/403/weightsCheckpoints/weights-checkp-008-0.968.hdf5
# Epoch 9/10
# 4982178/4982178 [==============================] - 178s 36us/step - loss: 0.0744 - acc: 0.9708 - val_loss: 0.0752 - val_acc: 0.9706
#
# Epoch 00009: val_acc improved from 0.96815 to 0.97060, saving model to Results/403/weightsCheckpoints/weights-checkp-009-0.971.hdf5
# Epoch 10/10
# 4982178/4982178 [==============================] - 177s 36us/step - loss: 0.0713 - acc: 0.9722 - val_loss: 0.0796 - val_acc: 0.9694
#
# Epoch 00010: val_acc did not improve from 0.97060
# Training done
# Calculating score
# 2453910/2453910 [==============================] - 132s 54us/step
# (4982178, 4, 8, 8)
# Evaluated test loss: 0.07962308797156034
# Evaluated test accuracy: 0.9694149337180256
# Saving results to dir 403
# Saving history...
# Saving weights...
# Saving figures...
# Saving summary...
# Saving tensorboard logs...
# All done saving stuff!
# Loading first 0 layers from results Results/103/weights.hdf5,
# - Resetting layer nr 1: <keras.layers.convolutional.Conv2D object at 0x7fe536516c88>
# - Resetting layer nr 2: <keras.layers.convolutional.Conv2D object at 0x7fe536516be0>
# - Resetting layer nr 3: <keras.layers.convolutional.Conv2D object at 0x7fe4c2f084a8>
# - Resetting layer nr 4: <keras.layers.convolutional.Conv2D object at 0x7fe4c32c36a0>
# - Resetting layer nr 5: <keras.layers.convolutional.Conv2D object at 0x7fe4c2f275c0>
# - Resetting layer nr 6: <keras.layers.convolutional.Conv2D object at 0x7fe4c324a278>
# - Resetting layer nr 7: <keras.layers.convolutional.Conv2D object at 0x7fe4c32645f8>
# - Skipping layer nr 8: <keras.layers.core.Flatten object at 0x7fe4c327c4a8>
# - Resetting layer nr 9: <keras.layers.core.Dense object at 0x7fe4c327cef0>
# Save dir: Results/405/
# Creating save dir
# Done generating results dir Results/405/
# Saving weights to Results/405/weightsCheckpoints/
# Train on 4982178 samples, validate on 2453910 samples
# Epoch 1/10
# 4982178/4982178 [==============================] - 179s 36us/step - loss: 0.2668 - acc: 0.8851 - val_loss: 0.1854 - val_acc: 0.9225
#
# Epoch 00001: val_acc improved from -inf to 0.92248, saving model to Results/405/weightsCheckpoints/weights-checkp-001-0.922.hdf5
# Epoch 2/10
# 4982178/4982178 [==============================] - 179s 36us/step - loss: 0.1558 - acc: 0.9354 - val_loss: 0.1460 - val_acc: 0.9397
#
# Epoch 00002: val_acc improved from 0.92248 to 0.93966, saving model to Results/405/weightsCheckpoints/weights-checkp-002-0.940.hdf5
# Epoch 3/10
# 4982178/4982178 [==============================] - 179s 36us/step - loss: 0.1280 - acc: 0.9476 - val_loss: 0.1207 - val_acc: 0.9509
#
# Epoch 00003: val_acc improved from 0.93966 to 0.95093, saving model to Results/405/weightsCheckpoints/weights-checkp-003-0.951.hdf5
# Epoch 4/10
# 4982178/4982178 [==============================] - 179s 36us/step - loss: 0.1119 - acc: 0.9547 - val_loss: 0.1092 - val_acc: 0.9561
#
# Epoch 00004: val_acc improved from 0.95093 to 0.95613, saving model to Results/405/weightsCheckpoints/weights-checkp-004-0.956.hdf5
# Epoch 5/10
# 4982178/4982178 [==============================] - 179s 36us/step - loss: 0.1012 - acc: 0.9593 - val_loss: 0.1024 - val_acc: 0.9590
#
# Epoch 00005: val_acc improved from 0.95613 to 0.95898, saving model to Results/405/weightsCheckpoints/weights-checkp-005-0.959.hdf5
# Epoch 6/10
# 4982178/4982178 [==============================] - 179s 36us/step - loss: 0.0938 - acc: 0.9626 - val_loss: 0.0975 - val_acc: 0.9613
#
# Epoch 00006: val_acc improved from 0.95898 to 0.96134, saving model to Results/405/weightsCheckpoints/weights-checkp-006-0.961.hdf5
# Epoch 7/10
# 4982178/4982178 [==============================] - 179s 36us/step - loss: 0.0881 - acc: 0.9649 - val_loss: 0.0970 - val_acc: 0.9615
#
# Epoch 00007: val_acc improved from 0.96134 to 0.96152, saving model to Results/405/weightsCheckpoints/weights-checkp-007-0.962.hdf5
# Epoch 8/10
# 4982178/4982178 [==============================] - 179s 36us/step - loss: 0.0835 - acc: 0.9669 - val_loss: 0.0947 - val_acc: 0.9628
#
# Epoch 00008: val_acc improved from 0.96152 to 0.96279, saving model to Results/405/weightsCheckpoints/weights-checkp-008-0.963.hdf5
# Epoch 9/10
# 4982178/4982178 [==============================] - 179s 36us/step - loss: 0.0800 - acc: 0.9684 - val_loss: 0.0826 - val_acc: 0.9677
#
# Epoch 00009: val_acc improved from 0.96279 to 0.96771, saving model to Results/405/weightsCheckpoints/weights-checkp-009-0.968.hdf5
# Epoch 10/10
# 4982178/4982178 [==============================] - 179s 36us/step - loss: 0.0769 - acc: 0.9697 - val_loss: 0.0820 - val_acc: 0.9678
#
# Epoch 00010: val_acc improved from 0.96771 to 0.96778, saving model to Results/405/weightsCheckpoints/weights-checkp-010-0.968.hdf5
# Training done
# Calculating score
# 2453910/2453910 [==============================] - 132s 54us/step
# (4982178, 4, 8, 8)
# Evaluated test loss: 0.0819864572543748
# Evaluated test accuracy: 0.9677751017763487
# Saving results to dir 405
# Saving history...
# Saving weights...
# Saving figures...
# Saving summary...
# Saving tensorboard logs...
# All done saving stuff!
# Loading first 0 layers from results Results/103/weights.hdf5,
# - Resetting layer nr 1: <keras.layers.convolutional.Conv2D object at 0x7fe536516c88>
# - Resetting layer nr 2: <keras.layers.convolutional.Conv2D object at 0x7fe536516be0>
# - Resetting layer nr 3: <keras.layers.convolutional.Conv2D object at 0x7fe4c2f084a8>
# - Resetting layer nr 4: <keras.layers.convolutional.Conv2D object at 0x7fe4c32c36a0>
# - Resetting layer nr 5: <keras.layers.convolutional.Conv2D object at 0x7fe4c2f275c0>
# - Resetting layer nr 6: <keras.layers.convolutional.Conv2D object at 0x7fe4c324a278>
# - Resetting layer nr 7: <keras.layers.convolutional.Conv2D object at 0x7fe4c32645f8>
# - Skipping layer nr 8: <keras.layers.core.Flatten object at 0x7fe4c327c4a8>
# - Resetting layer nr 9: <keras.layers.core.Dense object at 0x7fe4c327cef0>
# Save dir: Results/407/
# Creating save dir
# Done generating results dir Results/407/
# Saving weights to Results/407/weightsCheckpoints/
# Train on 4982178 samples, validate on 2453910 samples
# Epoch 1/10
# 4982178/4982178 [==============================] - 179s 36us/step - loss: 0.2709 - acc: 0.8837 - val_loss: 0.1916 - val_acc: 0.9201
#
# Epoch 00001: val_acc improved from -inf to 0.92007, saving model to Results/407/weightsCheckpoints/weights-checkp-001-0.920.hdf5
# Epoch 2/10
# 4982178/4982178 [==============================] - 179s 36us/step - loss: 0.1637 - acc: 0.9320 - val_loss: 0.1456 - val_acc: 0.9403
#
# Epoch 00002: val_acc improved from 0.92007 to 0.94028, saving model to Results/407/weightsCheckpoints/weights-checkp-002-0.940.hdf5
# Epoch 3/10
# 4982178/4982178 [==============================] - 179s 36us/step - loss: 0.1323 - acc: 0.9460 - val_loss: 0.1239 - val_acc: 0.9499
#
# Epoch 00003: val_acc improved from 0.94028 to 0.94989, saving model to Results/407/weightsCheckpoints/weights-checkp-003-0.950.hdf5
# Epoch 4/10
# 4982178/4982178 [==============================] - 179s 36us/step - loss: 0.1138 - acc: 0.9543 - val_loss: 0.1103 - val_acc: 0.9560
#
# Epoch 00004: val_acc improved from 0.94989 to 0.95599, saving model to Results/407/weightsCheckpoints/weights-checkp-004-0.956.hdf5
# Epoch 5/10
# 4982178/4982178 [==============================] - 179s 36us/step - loss: 0.1020 - acc: 0.9594 - val_loss: 0.1058 - val_acc: 0.9581
#
# Epoch 00005: val_acc improved from 0.95599 to 0.95808, saving model to Results/407/weightsCheckpoints/weights-checkp-005-0.958.hdf5
# Epoch 6/10
# 4982178/4982178 [==============================] - 179s 36us/step - loss: 0.0936 - acc: 0.9630 - val_loss: 0.0931 - val_acc: 0.9635
#
# Epoch 00006: val_acc improved from 0.95808 to 0.96348, saving model to Results/407/weightsCheckpoints/weights-checkp-006-0.963.hdf5
# Epoch 7/10
# 4982178/4982178 [==============================] - 179s 36us/step - loss: 0.0874 - acc: 0.9656 - val_loss: 0.0946 - val_acc: 0.9632
#
# Epoch 00007: val_acc did not improve from 0.96348
# Epoch 8/10
# 4982178/4982178 [==============================] - 180s 36us/step - loss: 0.0829 - acc: 0.9675 - val_loss: 0.0890 - val_acc: 0.9653
#
# Epoch 00008: val_acc improved from 0.96348 to 0.96531, saving model to Results/407/weightsCheckpoints/weights-checkp-008-0.965.hdf5
# Epoch 9/10
# 4982178/4982178 [==============================] - 179s 36us/step - loss: 0.0791 - acc: 0.9691 - val_loss: 0.0913 - val_acc: 0.9649
#
# Epoch 00009: val_acc did not improve from 0.96531
# Epoch 10/10
# 4982178/4982178 [==============================] - 179s 36us/step - loss: 0.0758 - acc: 0.9705 - val_loss: 0.0846 - val_acc: 0.9670
#
# Epoch 00010: val_acc improved from 0.96531 to 0.96698, saving model to Results/407/weightsCheckpoints/weights-checkp-010-0.967.hdf5
# Training done
# Calculating score
# 2453910/2453910 [==============================] - 132s 54us/step
# (4982178, 4, 8, 8)
# Evaluated test loss: 0.08463727644099056
# Evaluated test accuracy: 0.9669767839896328
# Saving results to dir 407
# Saving history...
# Saving weights...
# Saving figures...
# Saving summary...
# Saving tensorboard logs...
# All done saving stuff!
# Loading first 0 layers from results Results/103/weights.hdf5,
# - Resetting layer nr 1: <keras.layers.convolutional.Conv2D object at 0x7fe536516c88>
# - Resetting layer nr 2: <keras.layers.convolutional.Conv2D object at 0x7fe536516be0>
# - Resetting layer nr 3: <keras.layers.convolutional.Conv2D object at 0x7fe4c2f084a8>
# - Resetting layer nr 4: <keras.layers.convolutional.Conv2D object at 0x7fe4c32c36a0>
# - Resetting layer nr 5: <keras.layers.convolutional.Conv2D object at 0x7fe4c2f275c0>
# - Resetting layer nr 6: <keras.layers.convolutional.Conv2D object at 0x7fe4c324a278>
# - Resetting layer nr 7: <keras.layers.convolutional.Conv2D object at 0x7fe4c32645f8>
# - Skipping layer nr 8: <keras.layers.core.Flatten object at 0x7fe4c327c4a8>
# - Resetting layer nr 9: <keras.layers.core.Dense object at 0x7fe4c327cef0>
# Save dir: Results/409/
# Creating save dir
# Done generating results dir Results/409/
# Saving weights to Results/409/weightsCheckpoints/
# Train on 4982178 samples, validate on 2453910 samples
# Epoch 1/10
# 4982178/4982178 [==============================] - 177s 35us/step - loss: 0.2648 - acc: 0.8846 - val_loss: 0.1835 - val_acc: 0.9223
#
# Epoch 00001: val_acc improved from -inf to 0.92230, saving model to Results/409/weightsCheckpoints/weights-checkp-001-0.922.hdf5
# Epoch 2/10
# 4982178/4982178 [==============================] - 177s 36us/step - loss: 0.1534 - acc: 0.9358 - val_loss: 0.1364 - val_acc: 0.9435
#
# Epoch 00002: val_acc improved from 0.92230 to 0.94350, saving model to Results/409/weightsCheckpoints/weights-checkp-002-0.944.hdf5
# Epoch 3/10
# 4982178/4982178 [==============================] - 177s 36us/step - loss: 0.1218 - acc: 0.9503 - val_loss: 0.1113 - val_acc: 0.9555
#
# Epoch 00003: val_acc improved from 0.94350 to 0.95547, saving model to Results/409/weightsCheckpoints/weights-checkp-003-0.955.hdf5
# Epoch 4/10
# 4982178/4982178 [==============================] - 177s 36us/step - loss: 0.1041 - acc: 0.9583 - val_loss: 0.1007 - val_acc: 0.9599
#
# Epoch 00004: val_acc improved from 0.95547 to 0.95988, saving model to Results/409/weightsCheckpoints/weights-checkp-004-0.960.hdf5
# Epoch 5/10
# 4982178/4982178 [==============================] - 177s 36us/step - loss: 0.0934 - acc: 0.9629 - val_loss: 0.0919 - val_acc: 0.9636
#
# Epoch 00005: val_acc improved from 0.95988 to 0.96357, saving model to Results/409/weightsCheckpoints/weights-checkp-005-0.964.hdf5
# Epoch 6/10
# 4982178/4982178 [==============================] - 177s 36us/step - loss: 0.0860 - acc: 0.9660 - val_loss: 0.0901 - val_acc: 0.9647
#
# Epoch 00006: val_acc improved from 0.96357 to 0.96467, saving model to Results/409/weightsCheckpoints/weights-checkp-006-0.965.hdf5
# Epoch 7/10
# 4982178/4982178 [==============================] - 177s 36us/step - loss: 0.0804 - acc: 0.9685 - val_loss: 0.0875 - val_acc: 0.9657
#
# Epoch 00007: val_acc improved from 0.96467 to 0.96573, saving model to Results/409/weightsCheckpoints/weights-checkp-007-0.966.hdf5
# Epoch 8/10
# 4982178/4982178 [==============================] - 177s 36us/step - loss: 0.0764 - acc: 0.9701 - val_loss: 0.0790 - val_acc: 0.9691
#
# Epoch 00008: val_acc improved from 0.96573 to 0.96913, saving model to Results/409/weightsCheckpoints/weights-checkp-008-0.969.hdf5
# Epoch 9/10
# 4982178/4982178 [==============================] - 177s 36us/step - loss: 0.0730 - acc: 0.9715 - val_loss: 0.0773 - val_acc: 0.9700
#
# Epoch 00009: val_acc improved from 0.96913 to 0.96999, saving model to Results/409/weightsCheckpoints/weights-checkp-009-0.970.hdf5
# Epoch 10/10
# 4982178/4982178 [==============================] - 177s 36us/step - loss: 0.0702 - acc: 0.9726 - val_loss: 0.0769 - val_acc: 0.9702
#
# Epoch 00010: val_acc improved from 0.96999 to 0.97019, saving model to Results/409/weightsCheckpoints/weights-checkp-010-0.970.hdf5
# Training done
# Calculating score
# 2453910/2453910 [==============================] - 132s 54us/step
# (4982178, 4, 8, 8)
# Evaluated test loss: 0.07693483655800241
# Evaluated test accuracy: 0.9701892082431711
# Saving results to dir 409
# Saving history...
# Saving weights...
# Saving figures...
# Saving summary...
# Saving tensorboard logs...
# All done saving stuff!
# Loading first 0 layers from results Results/103/weights.hdf5,
# - Resetting layer nr 1: <keras.layers.convolutional.Conv2D object at 0x7fe536516c88>
# - Resetting layer nr 2: <keras.layers.convolutional.Conv2D object at 0x7fe536516be0>
# - Resetting layer nr 3: <keras.layers.convolutional.Conv2D object at 0x7fe4c2f084a8>
# - Resetting layer nr 4: <keras.layers.convolutional.Conv2D object at 0x7fe4c32c36a0>
# - Resetting layer nr 5: <keras.layers.convolutional.Conv2D object at 0x7fe4c2f275c0>
# - Resetting layer nr 6: <keras.layers.convolutional.Conv2D object at 0x7fe4c324a278>
# - Resetting layer nr 7: <keras.layers.convolutional.Conv2D object at 0x7fe4c32645f8>
# - Skipping layer nr 8: <keras.layers.core.Flatten object at 0x7fe4c327c4a8>
# - Resetting layer nr 9: <keras.layers.core.Dense object at 0x7fe4c327cef0>
# Save dir: Results/411/
# Creating save dir
# Done generating results dir Results/411/
# Saving weights to Results/411/weightsCheckpoints/
# Train on 4982178 samples, validate on 2453910 samples
# Epoch 1/10
# 4982178/4982178 [==============================] - 179s 36us/step - loss: 0.2822 - acc: 0.8771 - val_loss: 0.1905 - val_acc: 0.9185
#
# Epoch 00001: val_acc improved from -inf to 0.91849, saving model to Results/411/weightsCheckpoints/weights-checkp-001-0.918.hdf5
# Epoch 2/10
# 4982178/4982178 [==============================] - 179s 36us/step - loss: 0.1677 - acc: 0.9286 - val_loss: 0.1556 - val_acc: 0.9345
#
# Epoch 00002: val_acc improved from 0.91849 to 0.93451, saving model to Results/411/weightsCheckpoints/weights-checkp-002-0.935.hdf5
# Epoch 3/10
# 4982178/4982178 [==============================] - 179s 36us/step - loss: 0.1402 - acc: 0.9412 - val_loss: 0.1330 - val_acc: 0.9448
#
# Epoch 00003: val_acc improved from 0.93451 to 0.94484, saving model to Results/411/weightsCheckpoints/weights-checkp-003-0.945.hdf5
# Epoch 4/10
# 4982178/4982178 [==============================] - 179s 36us/step - loss: 0.1248 - acc: 0.9483 - val_loss: 0.1299 - val_acc: 0.9471
#
# Epoch 00004: val_acc improved from 0.94484 to 0.94710, saving model to Results/411/weightsCheckpoints/weights-checkp-004-0.947.hdf5
# Epoch 5/10
# 4982178/4982178 [==============================] - 179s 36us/step - loss: 0.1143 - acc: 0.9531 - val_loss: 0.1202 - val_acc: 0.9512
#
# Epoch 00005: val_acc improved from 0.94710 to 0.95118, saving model to Results/411/weightsCheckpoints/weights-checkp-005-0.951.hdf5
# Epoch 6/10
# 4982178/4982178 [==============================] - 180s 36us/step - loss: 0.1061 - acc: 0.9567 - val_loss: 0.1135 - val_acc: 0.9541
#
# Epoch 00006: val_acc improved from 0.95118 to 0.95406, saving model to Results/411/weightsCheckpoints/weights-checkp-006-0.954.hdf5
# Epoch 7/10
# 4982178/4982178 [==============================] - 179s 36us/step - loss: 0.1001 - acc: 0.9595 - val_loss: 0.1022 - val_acc: 0.9585
#
# Epoch 00007: val_acc improved from 0.95406 to 0.95845, saving model to Results/411/weightsCheckpoints/weights-checkp-007-0.958.hdf5
# Epoch 8/10
# 4982178/4982178 [==============================] - 180s 36us/step - loss: 0.0952 - acc: 0.9617 - val_loss: 0.0972 - val_acc: 0.9615
#
# Epoch 00008: val_acc improved from 0.95845 to 0.96148, saving model to Results/411/weightsCheckpoints/weights-checkp-008-0.961.hdf5
# Epoch 9/10
# 4982178/4982178 [==============================] - 180s 36us/step - loss: 0.0910 - acc: 0.9635 - val_loss: 0.0966 - val_acc: 0.9615
#
# Epoch 00009: val_acc improved from 0.96148 to 0.96148, saving model to Results/411/weightsCheckpoints/weights-checkp-009-0.961.hdf5
# Epoch 10/10
# 4982178/4982178 [==============================] - 180s 36us/step - loss: 0.0879 - acc: 0.9649 - val_loss: 0.1053 - val_acc: 0.9590
#
# Epoch 00010: val_acc did not improve from 0.96148
# Training done
# Calculating score
# 2453910/2453910 [==============================] - 134s 54us/step
# (4982178, 4, 8, 8)
# Evaluated test loss: 0.10526636307779177
# Evaluated test accuracy: 0.9589956436870137
# Saving results to dir 411
# Saving history...
# Saving weights...
# Saving figures...
# Saving summary...
# Saving tensorboard logs...
# All done saving stuff!
# =========== At layer 1 of 8 ===========
# Loading first 1 layers from results Results/103/weights.hdf5,
# - Resetting layer nr 2: <keras.layers.convolutional.Conv2D object at 0x7fe536516be0>
# - Resetting layer nr 3: <keras.layers.convolutional.Conv2D object at 0x7fe4c2f084a8>
# - Resetting layer nr 4: <keras.layers.convolutional.Conv2D object at 0x7fe4c32c36a0>
# - Resetting layer nr 5: <keras.layers.convolutional.Conv2D object at 0x7fe4c2f275c0>
# - Resetting layer nr 6: <keras.layers.convolutional.Conv2D object at 0x7fe4c324a278>
# - Resetting layer nr 7: <keras.layers.convolutional.Conv2D object at 0x7fe4c32645f8>
# - Skipping layer nr 8: <keras.layers.core.Flatten object at 0x7fe4c327c4a8>
# - Resetting layer nr 9: <keras.layers.core.Dense object at 0x7fe4c327cef0>
# Save dir: Results/413/
# Creating save dir
# Done generating results dir Results/413/
# Saving weights to Results/413/weightsCheckpoints/
# Train on 4982178 samples, validate on 2453910 samples
# Epoch 1/10
# 4982178/4982178 [==============================] - 180s 36us/step - loss: 0.2497 - acc: 0.8923 - val_loss: 0.1689 - val_acc: 0.9283
#
# Epoch 00001: val_acc improved from -inf to 0.92835, saving model to Results/413/weightsCheckpoints/weights-checkp-001-0.928.hdf5
# Epoch 2/10
# 4982178/4982178 [==============================] - 179s 36us/step - loss: 0.1509 - acc: 0.9367 - val_loss: 0.1376 - val_acc: 0.9428
#
# Epoch 00002: val_acc improved from 0.92835 to 0.94282, saving model to Results/413/weightsCheckpoints/weights-checkp-002-0.943.hdf5
# Epoch 3/10
# 4982178/4982178 [==============================] - 179s 36us/step - loss: 0.1245 - acc: 0.9485 - val_loss: 0.1200 - val_acc: 0.9507
#
# Epoch 00003: val_acc improved from 0.94282 to 0.95066, saving model to Results/413/weightsCheckpoints/weights-checkp-003-0.951.hdf5
# Epoch 4/10
# 4982178/4982178 [==============================] - 179s 36us/step - loss: 0.1088 - acc: 0.9558 - val_loss: 0.1062 - val_acc: 0.9570
#
# Epoch 00004: val_acc improved from 0.95066 to 0.95698, saving model to Results/413/weightsCheckpoints/weights-checkp-004-0.957.hdf5
# Epoch 5/10
# 4982178/4982178 [==============================] - 179s 36us/step - loss: 0.0979 - acc: 0.9605 - val_loss: 0.1003 - val_acc: 0.9603
#
# Epoch 00005: val_acc improved from 0.95698 to 0.96027, saving model to Results/413/weightsCheckpoints/weights-checkp-005-0.960.hdf5
# Epoch 6/10
# 4982178/4982178 [==============================] - 180s 36us/step - loss: 0.0905 - acc: 0.9639 - val_loss: 0.0915 - val_acc: 0.9634
#
# Epoch 00006: val_acc improved from 0.96027 to 0.96337, saving model to Results/413/weightsCheckpoints/weights-checkp-006-0.963.hdf5
# Epoch 7/10
# 4982178/4982178 [==============================] - 181s 36us/step - loss: 0.0849 - acc: 0.9662 - val_loss: 0.0880 - val_acc: 0.9652
#
# Epoch 00007: val_acc improved from 0.96337 to 0.96525, saving model to Results/413/weightsCheckpoints/weights-checkp-007-0.965.hdf5
# Epoch 8/10
# 4982178/4982178 [==============================] - 180s 36us/step - loss: 0.0805 - acc: 0.9682 - val_loss: 0.0838 - val_acc: 0.9671
#
# Epoch 00008: val_acc improved from 0.96525 to 0.96707, saving model to Results/413/weightsCheckpoints/weights-checkp-008-0.967.hdf5
# Epoch 9/10
# 4982178/4982178 [==============================] - 181s 36us/step - loss: 0.0768 - acc: 0.9697 - val_loss: 0.0810 - val_acc: 0.9685
#
# Epoch 00009: val_acc improved from 0.96707 to 0.96850, saving model to Results/413/weightsCheckpoints/weights-checkp-009-0.968.hdf5
# Epoch 10/10
# 4982178/4982178 [==============================] - 181s 36us/step - loss: 0.0738 - acc: 0.9711 - val_loss: 0.0899 - val_acc: 0.9653
#
# Epoch 00010: val_acc did not improve from 0.96850
# Training done
# Calculating score
# 2453910/2453910 [==============================] - 132s 54us/step
# (4982178, 4, 8, 8)
# Evaluated test loss: 0.08993791527574627
# Evaluated test accuracy: 0.9653402121512199
# Saving results to dir 413
# Saving history...
# Saving weights...
# Saving figures...
# Saving summary...
# Saving tensorboard logs...
# All done saving stuff!
# Loading first 1 layers from results Results/103/weights.hdf5,
# - Resetting layer nr 2: <keras.layers.convolutional.Conv2D object at 0x7fe536516be0>
# - Resetting layer nr 3: <keras.layers.convolutional.Conv2D object at 0x7fe4c2f084a8>
# - Resetting layer nr 4: <keras.layers.convolutional.Conv2D object at 0x7fe4c32c36a0>
# - Resetting layer nr 5: <keras.layers.convolutional.Conv2D object at 0x7fe4c2f275c0>
# - Resetting layer nr 6: <keras.layers.convolutional.Conv2D object at 0x7fe4c324a278>
# - Resetting layer nr 7: <keras.layers.convolutional.Conv2D object at 0x7fe4c32645f8>
# - Skipping layer nr 8: <keras.layers.core.Flatten object at 0x7fe4c327c4a8>
# - Resetting layer nr 9: <keras.layers.core.Dense object at 0x7fe4c327cef0>
# Save dir: Results/415/
# Creating save dir
# Done generating results dir Results/415/
# Saving weights to Results/415/weightsCheckpoints/
# Train on 4982178 samples, validate on 2453910 samples
# Epoch 1/10
# 4982178/4982178 [==============================] - 181s 36us/step - loss: 0.2464 - acc: 0.8939 - val_loss: 0.1674 - val_acc: 0.9296
#
# Epoch 00001: val_acc improved from -inf to 0.92959, saving model to Results/415/weightsCheckpoints/weights-checkp-001-0.930.hdf5
# Epoch 2/10
# 4982178/4982178 [==============================] - 182s 37us/step - loss: 0.1445 - acc: 0.9399 - val_loss: 0.1301 - val_acc: 0.9465
#
# Epoch 00002: val_acc improved from 0.92959 to 0.94650, saving model to Results/415/weightsCheckpoints/weights-checkp-002-0.947.hdf5
# Epoch 3/10
# 4982178/4982178 [==============================] - 181s 36us/step - loss: 0.1153 - acc: 0.9531 - val_loss: 0.1127 - val_acc: 0.9546
#
# Epoch 00003: val_acc improved from 0.94650 to 0.95461, saving model to Results/415/weightsCheckpoints/weights-checkp-003-0.955.hdf5
# Epoch 4/10
# 4982178/4982178 [==============================] - 181s 36us/step - loss: 0.0995 - acc: 0.9600 - val_loss: 0.1003 - val_acc: 0.9596
#
# Epoch 00004: val_acc improved from 0.95461 to 0.95959, saving model to Results/415/weightsCheckpoints/weights-checkp-004-0.960.hdf5
# Epoch 5/10
# 4982178/4982178 [==============================] - 181s 36us/step - loss: 0.0898 - acc: 0.9642 - val_loss: 0.0899 - val_acc: 0.9643
#
# Epoch 00005: val_acc improved from 0.95959 to 0.96429, saving model to Results/415/weightsCheckpoints/weights-checkp-005-0.964.hdf5
# Epoch 6/10
# 4982178/4982178 [==============================] - 181s 36us/step - loss: 0.0827 - acc: 0.9672 - val_loss: 0.0851 - val_acc: 0.9670
#
# Epoch 00006: val_acc improved from 0.96429 to 0.96700, saving model to Results/415/weightsCheckpoints/weights-checkp-006-0.967.hdf5
# Epoch 7/10
# 4982178/4982178 [==============================] - 181s 36us/step - loss: 0.0772 - acc: 0.9696 - val_loss: 0.0848 - val_acc: 0.9669
#
# Epoch 00007: val_acc did not improve from 0.96700
# Epoch 8/10
# 4982178/4982178 [==============================] - 181s 36us/step - loss: 0.0732 - acc: 0.9713 - val_loss: 0.0725 - val_acc: 0.9716
#
# Epoch 00008: val_acc improved from 0.96700 to 0.97158, saving model to Results/415/weightsCheckpoints/weights-checkp-008-0.972.hdf5
# Epoch 9/10
# 4982178/4982178 [==============================] - 181s 36us/step - loss: 0.0697 - acc: 0.9729 - val_loss: 0.0773 - val_acc: 0.9702
#
# Epoch 00009: val_acc did not improve from 0.97158
# Epoch 10/10
# 4982178/4982178 [==============================] - 180s 36us/step - loss: 0.0667 - acc: 0.9740 - val_loss: 0.0744 - val_acc: 0.9711
#
# Epoch 00010: val_acc did not improve from 0.97158
# Training done
# Calculating score
# 2453910/2453910 [==============================] - 132s 54us/step
# (4982178, 4, 8, 8)
# Evaluated test loss: 0.07441088935720991
# Evaluated test accuracy: 0.9710747337921929
# Saving results to dir 415
# Saving history...
# Saving weights...
# Saving figures...
# Saving summary...
# Saving tensorboard logs...
# All done saving stuff!
# Loading first 1 layers from results Results/103/weights.hdf5,
# - Resetting layer nr 2: <keras.layers.convolutional.Conv2D object at 0x7fe536516be0>
# - Resetting layer nr 3: <keras.layers.convolutional.Conv2D object at 0x7fe4c2f084a8>
# - Resetting layer nr 4: <keras.layers.convolutional.Conv2D object at 0x7fe4c32c36a0>
# - Resetting layer nr 5: <keras.layers.convolutional.Conv2D object at 0x7fe4c2f275c0>
# - Resetting layer nr 6: <keras.layers.convolutional.Conv2D object at 0x7fe4c324a278>
# - Resetting layer nr 7: <keras.layers.convolutional.Conv2D object at 0x7fe4c32645f8>
# - Skipping layer nr 8: <keras.layers.core.Flatten object at 0x7fe4c327c4a8>
# - Resetting layer nr 9: <keras.layers.core.Dense object at 0x7fe4c327cef0>
# Save dir: Results/417/
# Creating save dir
# Done generating results dir Results/417/
# Saving weights to Results/417/weightsCheckpoints/
# Train on 4982178 samples, validate on 2453910 samples
# Epoch 1/10
# 4982178/4982178 [==============================] - 180s 36us/step - loss: 0.2552 - acc: 0.8898 - val_loss: 0.1791 - val_acc: 0.9250
#
# Epoch 00001: val_acc improved from -inf to 0.92503, saving model to Results/417/weightsCheckpoints/weights-checkp-001-0.925.hdf5
# Epoch 2/10
# 4982178/4982178 [==============================] - 181s 36us/step - loss: 0.1521 - acc: 0.9360 - val_loss: 0.1368 - val_acc: 0.9426
#
# Epoch 00002: val_acc improved from 0.92503 to 0.94260, saving model to Results/417/weightsCheckpoints/weights-checkp-002-0.943.hdf5
# Epoch 3/10
# 4982178/4982178 [==============================] - 181s 36us/step - loss: 0.1249 - acc: 0.9485 - val_loss: 0.1183 - val_acc: 0.9515
#
# Epoch 00003: val_acc improved from 0.94260 to 0.95152, saving model to Results/417/weightsCheckpoints/weights-checkp-003-0.952.hdf5
# Epoch 4/10
# 4982178/4982178 [==============================] - 181s 36us/step - loss: 0.1089 - acc: 0.9557 - val_loss: 0.1122 - val_acc: 0.9551
#
# Epoch 00004: val_acc improved from 0.95152 to 0.95506, saving model to Results/417/weightsCheckpoints/weights-checkp-004-0.955.hdf5
# Epoch 5/10
# 4982178/4982178 [==============================] - 181s 36us/step - loss: 0.0980 - acc: 0.9605 - val_loss: 0.1006 - val_acc: 0.9596
#
# Epoch 00005: val_acc improved from 0.95506 to 0.95962, saving model to Results/417/weightsCheckpoints/weights-checkp-005-0.960.hdf5
# Epoch 6/10
# 4982178/4982178 [==============================] - 180s 36us/step - loss: 0.0897 - acc: 0.9641 - val_loss: 0.0897 - val_acc: 0.9644
#
# Epoch 00006: val_acc improved from 0.95962 to 0.96440, saving model to Results/417/weightsCheckpoints/weights-checkp-006-0.964.hdf5
# Epoch 7/10
# 4982178/4982178 [==============================] - 181s 36us/step - loss: 0.0841 - acc: 0.9666 - val_loss: 0.0919 - val_acc: 0.9636
#
# Epoch 00007: val_acc did not improve from 0.96440
# Epoch 8/10
# 4982178/4982178 [==============================] - 181s 36us/step - loss: 0.0794 - acc: 0.9687 - val_loss: 0.0868 - val_acc: 0.9657
#
# Epoch 00008: val_acc improved from 0.96440 to 0.96574, saving model to Results/417/weightsCheckpoints/weights-checkp-008-0.966.hdf5
# Epoch 9/10
# 4982178/4982178 [==============================] - 181s 36us/step - loss: 0.0756 - acc: 0.9703 - val_loss: 0.0801 - val_acc: 0.9685
#
# Epoch 00009: val_acc improved from 0.96574 to 0.96849, saving model to Results/417/weightsCheckpoints/weights-checkp-009-0.968.hdf5
# Epoch 10/10
# 4982178/4982178 [==============================] - 180s 36us/step - loss: 0.0729 - acc: 0.9714 - val_loss: 0.0784 - val_acc: 0.9697
#
# Epoch 00010: val_acc improved from 0.96849 to 0.96967, saving model to Results/417/weightsCheckpoints/weights-checkp-010-0.970.hdf5
# Training done
# Calculating score
# 2453910/2453910 [==============================] - 133s 54us/step
# (4982178, 4, 8, 8)
# Evaluated test loss: 0.07839635301096737
# Evaluated test accuracy: 0.9696741119274953
# Saving results to dir 417
# Saving history...
# Saving weights...
# Saving figures...
# Saving summary...
# Saving tensorboard logs...
# All done saving stuff!
# Loading first 1 layers from results Results/103/weights.hdf5,
# - Resetting layer nr 2: <keras.layers.convolutional.Conv2D object at 0x7fe536516be0>
# - Resetting layer nr 3: <keras.layers.convolutional.Conv2D object at 0x7fe4c2f084a8>
# - Resetting layer nr 4: <keras.layers.convolutional.Conv2D object at 0x7fe4c32c36a0>
# - Resetting layer nr 5: <keras.layers.convolutional.Conv2D object at 0x7fe4c2f275c0>
# - Resetting layer nr 6: <keras.layers.convolutional.Conv2D object at 0x7fe4c324a278>
# - Resetting layer nr 7: <keras.layers.convolutional.Conv2D object at 0x7fe4c32645f8>
# - Skipping layer nr 8: <keras.layers.core.Flatten object at 0x7fe4c327c4a8>
# - Resetting layer nr 9: <keras.layers.core.Dense object at 0x7fe4c327cef0>
# Save dir: Results/419/
# Creating save dir
# Done generating results dir Results/419/
# Saving weights to Results/419/weightsCheckpoints/
# Train on 4982178 samples, validate on 2453910 samples
# Epoch 1/10
# 4982178/4982178 [==============================] - 181s 36us/step - loss: 0.2477 - acc: 0.8936 - val_loss: 0.1660 - val_acc: 0.9303
#
# Epoch 00001: val_acc improved from -inf to 0.93026, saving model to Results/419/weightsCheckpoints/weights-checkp-001-0.930.hdf5
# Epoch 2/10
# 2691584/4982178 [===============>..............] - ETA: 1:13 - loss: 0.1513 - acc: 0.9370
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~/projects/Endnet/mainCode/arena.py in <module>()
#      39
#      40             # train
# ---> 41             fitHistory, logDir = trainModel(resID, model, saveWeightsCheckpoints, saveTensorboardLogs)
#      42
#      43             # score and save accuracy
#
# ~/projects/Endnet/mainCode/arena.py in trainModel(resID, model, saveWeightsCheckpoints, saveTensorBoardLogs)
#     497                            epochs=epochs,
#     498                            verbose=1,
# --> 499                            callbacks = callbacksArr,
#     500 #                          .format(resID,nPi, initWeightsId, kpm, int(time() - 1500000000)))],
#     501                            validation_data=(X_test, y_test))
#
# ~/anaconda3/envs/endnetGpu/lib/python3.5/site-packages/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, **kwargs)
#    1035                                         initial_epoch=initial_epoch,
#    1036                                         steps_per_epoch=steps_per_epoch,
# -> 1037                                         validation_steps=validation_steps)
#    1038
#    1039     def evaluate(self, x=None, y=None,
#
# ~/anaconda3/envs/endnetGpu/lib/python3.5/site-packages/keras/engine/training_arrays.py in fit_loop(model, f, ins, out_labels, batch_size, epochs, verbose, callbacks, val_f, val_ins, shuffle, callback_metrics, initial_epoch, steps_per_epoch, validation_steps)
#     197                     ins_batch[i] = ins_batch[i].toarray()
#     198
# --> 199                 outs = f(ins_batch)
#     200                 outs = to_list(outs)
#     201                 for l, o in zip(out_labels, outs):
#
# ~/anaconda3/envs/endnetGpu/lib/python3.5/site-packages/keras/backend/tensorflow_backend.py in __call__(self, inputs)
#    2664                 return self._legacy_call(inputs)
#    2665
# -> 2666             return self._call(inputs)
#    2667         else:
#    2668             if py_any(is_tensor(x) for x in inputs):
#
# ~/anaconda3/envs/endnetGpu/lib/python3.5/site-packages/keras/backend/tensorflow_backend.py in _call(self, inputs)
#    2634                                 symbol_vals,
#    2635                                 session)
# -> 2636         fetched = self._callable_fn(*array_vals)
#    2637         return fetched[:len(self.outputs)]
#    2638
#
# ~/anaconda3/envs/endnetGpu/lib/python3.5/site-packages/tensorflow/python/client/session.py in __call__(self, *args, **kwargs)
#    1380           ret = tf_session.TF_SessionRunCallable(
#    1381               self._session._session, self._handle, args, status,
# -> 1382               run_metadata_ptr)
#    1383         if run_metadata:
#    1384           proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# KeyboardInterrupt:

# %%
# 4n4 NoFreeze and average
# %run -i 'arena.py'

# Parameters
# sourceNet = '103' # trained on 3pc from scratch
sourceNet = '107' # trained on 4pc from scratch
freeze = False
resSaveFile = '4n4noFreeze'
epochs = 10
averageOver = 10
expDescr = "Bengio 4n4 - no freeze = {} - average over {} runs".format(str(freeze), averageOver)

saveEveryRun = True # save stuff in results dir
saveWeightsCheckpoints = True # save chkp in results dit
saveTensorboardLogs = True # save logs in ./logs dir
resSaveFile = resSaveFile + '-{} run average'.format(averageOver)
fractionOfDataToUse = 1
plotDuringTraining = False
loadWeights = False 
askForConfirmation = False
saveDir = 'bengioResults'

X_train, X_test, y_train, y_test = loadData()
model, nnStr = createModel()
results = []
accumulatedScore = 0
layersCount = len(model.layers)

for copyFirstNLayers in range(layersCount + 1):
    print('=========== At layer {} of {} ==========='.format(copyFirstNLayers, layersCount - 1))
    if copyFirstNLayers != layersCount - 1:
        accumulatedScore = 0
        for a in range(averageOver):
            model = loadNFirstLayers(model, sourceNet, copyFirstNLayers , freeze)

            if saveEveryRun:
                resID = genNextResultsDir(model)
                #add freeze and some tl parameters to save dir

            # train
            fitHistory, logDir = trainModel(resID, model, saveWeightsCheckpoints, saveTensorboardLogs)

            # score and save accuracy
            score = calcScore(model)
            if saveEveryRun:
                saveTrainResults(resID, model, logDir, score, copyFirstNLayers)
            
            # update Return
            accumulatedScore += score[1]
        results.append(accumulatedScore/averageOver)

        # save results incrementally to txt file
        save_obj(saveDir, resSaveFile, results)
        with open(saveDir + '/' + str(resSaveFile) + '.txt','w') as file:
            file.write(str(results))
            
        # to load:
        # results = load_obj('temp','3n4.txt')
print('\n Final Results: {}'.format(results))

# %%
# Train, evaluate and save 
# %run -i 'arena.py'
# %reload_ext autoreload
plotDuringTraining = True
fractionOfDataToUse = 0.01
model, nnStr = createModel()
# resID = genNextResultsDir(model)
X_train, X_test, y_train, y_test = loadData()
fitHistory, logDir = trainModel(resID, model)
# score = calcScoreBigData(model)
# score = calcScore(model)
# saveTrainResults(resID, model, logDir, score)
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_148 (Conv2D)          (None, 16, 7, 7)          272
# _________________________________________________________________
# conv2d_149 (Conv2D)          (None, 15, 6, 32)         928
# _________________________________________________________________
# conv2d_150 (Conv2D)          (None, 14, 5, 32)         4128
# _________________________________________________________________
# conv2d_151 (Conv2D)          (None, 13, 4, 64)         8256
# _________________________________________________________________
# conv2d_152 (Conv2D)          (None, 12, 3, 128)        32896
# _________________________________________________________________
# conv2d_153 (Conv2D)          (None, 11, 2, 128)        65664
# _________________________________________________________________
# conv2d_154 (Conv2D)          (None, 10, 1, 128)        65664
# _________________________________________________________________
# flatten_22 (Flatten)         (None, 1280)              0
# _________________________________________________________________
# dense_22 (Dense)             (None, 3)                 3843
# =================================================================
# Total params: 181,651
# Trainable params: 181,651
# Non-trainable params: 0
# _________________________________________________________________
# Starting with random weights
# Done creating model
# X_train shape: (49821, 4, 8, 8)
# y_train shape: (49821, 1)
# X_test shape: (24539, 4, 8, 8)
# y_test shape: (24539, 1)
# 49821 train samples
# 24539 test samples
# Done loading dataset
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# ~/projects/Endnet/mainCode/arena.py in <module>()
#       7 # resID = genNextResultsDir(model)
#       8 X_train, X_test, y_train, y_test = loadData()
# ----> 9 fitHistory, logDir = trainModel(resID, model)
#      10 # score = calcScoreBigData(model)
#      11 # score = calcScore(model)
#
# ~/projects/Endnet/mainCode/arena.py in trainModel(resID, model, saveWeightsCheckpoints, saveTensorboardLogs)
#     469         callbacksArr.append(plot_losses)
#     470     if saveTensorboardLogs:
# --> 471         logDir = './logs/{}-{}pc-{}-{}KPM-{}'.format(resID,nPi, initWeightsId, kpm, expDescr, dateTime )
#     472         callbacksArr.append(keras.callbacks.TensorBoard(log_dir=logDir))
#     473
#
# UnboundLocalError: local variable 'initWeightsId' referenced before assignment
